# %% [markdown]
# <a href="https://colab.research.google.com/github/linhnguyen222/DPS-Silo/blob/master/pretrained_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Pre trained BERT model for full sentence multiclass classification

# %%
from platform import python_version
from pathlib import Path
import tensorflow as tf
import numpy as np

import pathlib
import pandas as pd
#from pytorch_pretrained_bert import BertTokenizer
import torch
from pandas import DataFrame


print(python_version())
print (tf.__version__)
# Out:
# 3.6.9
# 2.3.0

# %%
from google.colab import drive
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ####Helper functions to read in the data.

# %%
def read_data(directory):
    ids = []
    texts = []
    labels = []
    for f in directory.glob('*.txt'):
        id = f.name.replace('article', '').replace('.txt','')
        ids.append(id)
        texts.append(f.read_text())
        labels.append(parse_label(f.as_posix().replace('.txt', '.labels.tsv')))
    # labels can be empty 
    return ids, texts, labels

def clean_text(articles, ids):
    texts = []
    for article, id in zip(articles, ids):
        sentences = article.split('\n')
        start = 0
        end = -1
        res = []
        for sentence in sentences:
           start = end + 1
           end = start + len(sentence)  # length of sequence 
           if sentence != "": # if not empty line
               res.append([id, sentence, start, end])
        texts.append(res)
    return texts


def make_dataset(directory):
    ids, texts, labels = read_data(directory)
    texts = clean_text(texts, ids)
    res = []
    for text, label in zip(texts, labels):
        # making positive examples
        tmp = [] 
        pos_ind = [0] * len(text)
        for l in label:
            for i, sen in enumerate(text):
                if l[0] >= sen[2] and l[0] < sen[3] and l[1] > sen[3]:
                    l[4] = 1
                    tmp.append(sen + [l[0], sen[3], l[2], l[3], l[4]])
                    pos_ind[i] = 1
                    l[0] = sen[3] + 1
                elif l[0] != l[1] and l[0] >= sen[2] and l[0] < sen[3] and l[1] <= sen[3]: 
                    tmp.append(sen + l)
                    pos_ind[i] = 1
        # making negative examples
        dummy = [0, 0, 'O', 0, 0]
        for k, sen in enumerate(text):
            if pos_ind[k] != 1:
                tmp.append(sen+dummy)
        res.append(tmp)     
    return res
  
def parse_label(label_path):
    labels = []
    f= Path(label_path)
    
    if not f.exists():
        return labels

    for line in open(label_path):
        parts = line.strip().split('\t')
        labels.append([int(parts[2]), int(parts[3]), parts[1], 0, 0])
    labels = sorted(labels) 

    if labels:
        length = max([label[1] for label in labels]) 
        visit = np.zeros(length)
        res = []
        for label in labels:
            if sum(visit[label[0]:label[1]]):
                label[3] = 1
            else:
               visit[label[0]:label[1]] = 1
            res.append(label)
        return res 
    else:
        return labels

# %% [markdown]
# ####Importing train and test set and reading them in as dataframes.

# %%
#train set
dataset_train=make_dataset(Path('/content/drive/My Drive/DSP/data/protechn_corpus_eval/train'))
#test set
dataset_test=make_dataset(Path('/content/drive/My Drive/DSP/data/protechn_corpus_eval/test'))

# %%
#train dataframe
empty=[]
for i in dataset_train:
    
    temp=DataFrame(i, columns=['id', 'full_sent', 'start_sent', 'end_sent', 'start_prop', 'end_prop','prop', 'ex1', 'ex2' ])
    empty.append(temp)

df_train=pd.concat(empty)  
df_train = df_train.drop(['ex1'],axis =1).drop(['ex2'],axis =1)
df_train.prop.value_counts()
df_train=df_train.reset_index()
#del df['index']

df_train.head()
# Out:
#    index          id  ... end_prop                       prop
# 0      0  7618745059  ...     1872               Whataboutism
# 1      1  7618745059  ...     1976               Whataboutism
# 2      2  7618745059  ...     2388  Causal_Oversimplification
# 3      3  7618745059  ...     2782  Exaggeration,Minimisation
# 4      4  7618745059  ...        0                          O
#
# [5 rows x 8 columns]

# %% [markdown]
# #### We define a new column (called 'label') to turn string labels into integer labels by using a defined label dictionary that maps each propaganda technique to an integer representing that class.

# %%
"""
label_dict={}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label]=index
print(label_dict)
"""
label_dict={'O': 0, 'Black-and-White_Fallacy': 1, 'Loaded_Language': 2, 'Flag-Waving': 3, 
 'Name_Calling,Labeling': 4, 'Slogans': 5, 'Causal_Oversimplification': 6, 'Whataboutism': 7,
 'Exaggeration,Minimisation': 8, 'Doubt': 9, 'Appeal_to_Authority': 10, 'Repetition': 11, 'Appeal_to_fear-prejudice': 12,
 'Thought-terminating_Cliches': 13, 'Bandwagon': 14, 'Red_Herring': 15, 'Reductio_ad_hitlerum': 16,
 'Obfuscation,Intentional_Vagueness,Confusion': 17, 'Straw_Men': 18}

df_train['label']=df_train.prop.replace(label_dict)

# %%
df_train.head()
# Out:
#    index          id  ...                       prop  label
# 0      0  7618745059  ...               Whataboutism      7
# 1      1  7618745059  ...               Whataboutism      7
# 2      2  7618745059  ...  Causal_Oversimplification      6
# 3      3  7618745059  ...  Exaggeration,Minimisation      8
# 4      4  7618745059  ...                          O      0
#
# [5 rows x 9 columns]

# %%
df_train.dtypes
# Out:
# index          int64
# id            object
# full_sent     object
# start_sent     int64
# end_sent       int64
# start_prop     int64
# end_prop       int64
# prop          object
# label          int64
# dtype: object

# %%
type(df_train['full_sent'][0])
# Out:
# str

# %% [markdown]
# ####Dataset is imbalanced.

# %%
#data is not unitedly distributed in different classes i.e., we have a class imbalance
df_train.prop.value_counts()
# Out:
# O                                              10337
# Loaded_Language                                 1832
# Name_Calling,Labeling                            934
# Doubt                                            527
# Repetition                                       465
# Exaggeration,Minimisation                        401
# Appeal_to_fear-prejudice                         225
# Flag-Waving                                      216
# Causal_Oversimplification                        199
# Appeal_to_Authority                              129
# Black-and-White_Fallacy                          123
# Slogans                                          123
# Thought-terminating_Cliches                       72
# Whataboutism                                      59
# Reductio_ad_hitlerum                              48
# Red_Herring                                       26
# Bandwagon                                         13
# Straw_Men                                         12
# Obfuscation,Intentional_Vagueness,Confusion       11
# Name: prop, dtype: int64

# %%
df_train.label.value_counts()
# Out:
# 0     10337
# 2      1832
# 4       934
# 9       527
# 11      465
# 8       401
# 12      225
# 3       216
# 6       199
# 10      129
# 5       123
# 1       123
# 13       72
# 7        59
# 16       48
# 15       26
# 14       13
# 18       12
# 17       11
# Name: label, dtype: int64

# %%
#test dataframe
empty=[]
for i in dataset_test:
    
    temp=DataFrame(i, columns=['id', 'full_sent', 'start_sent', 'end_sent', 'start_prop', 'end_prop','prop', 'ex1', 'ex2' ])
    empty.append(temp)

df_test=pd.concat(empty)  
df_test = df_test.drop(['ex1'],axis =1).drop(['ex2'],axis =1)
df_test.prop.value_counts()
df_test=df_test.reset_index()
#del df['index']

df_test.head()
# Out:
#    index         id  ... end_prop             prop
# 0      0  111111133  ...      367  Loaded_Language
# 1      1  111111133  ...      465  Loaded_Language
# 2      2  111111133  ...      507  Loaded_Language
# 3      3  111111133  ...     1077  Loaded_Language
# 4      4  111111133  ...     1244  Loaded_Language
#
# [5 rows x 8 columns]

# %%
df_test['label']=df_test.prop.replace(label_dict)

# %%
df_test.head()
# Out:
#    index         id  ...             prop  label
# 0      0  111111133  ...  Loaded_Language      2
# 1      1  111111133  ...  Loaded_Language      2
# 2      2  111111133  ...  Loaded_Language      2
# 3      3  111111133  ...  Loaded_Language      2
# 4      4  111111133  ...  Loaded_Language      2
#
# [5 rows x 9 columns]

# %% [markdown]
# ####If we wanted to test this model with Augmented Data then we would be running these lines.

# %%
print("size of train set is: ", df_train.shape[0])
print("size of test set is: ", df_test.shape[0])
# Out:
# size of train set is:  15752
# size of test set is:  4490

# %%
#df_new=pd.read_csv(Path("/content/ADD_Context.csv"))
#df_new.head()
#df_new['Sentence'].isnull()
#df_new.isnull().values.any()
#df_new = df_new.dropna()
#df_new.isnull().values.any()
#df_new['label']=df_new.Label.replace(label_dict)
#df_new = df_new.rename(columns = {'Sentence':'full_sent'})

# %%
#df_train=df_new.iloc[0:20000, 0:5]

# %%
#df_train=df_train.reset_index()

# %%
#df_test=df_new.iloc[20000:, 0:5]

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (4.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.9.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)

# %% [markdown]
# ###The tokenizer takes in raw text and splits it into tokens. A token in this case is a numerical number that represents a certain word. Tensordataset makes it possible to use the data set in a pytorch environment.

# %%
from transformers import BertTokenizer
from torch.utils.data import TensorDataset

# %% [markdown]
# ###We use a pretrained BERT to encode our dataset.

# %%
#we will be using all lower case data
#do_lower_case converts every string to lower case as an uncased version of BERT will be used
tokenizer= BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# %% [markdown]
# ####Now we need to convert all our sentences from language into encoded form. Batch encode class can perform this as it can take multiple strings and convert them into tokens as is needed. This is done separately for train and test data.

# %%
""" As parameters it takes actual sentences, add special tokens will highlight when a sentences ends and when a new one begins, 
an attention mask tells the model where the relevant information in a sentence lies - as sentences do not originaly have the same length """

encoded_data_train=tokenizer.batch_encode_plus(df_train.full_sent.values, add_special_tokens=True, 
                                               return_attention_mask=True, pad_to_max_length=True, max_length=256, return_tensors='pt')

encoded_data_test=tokenizer.batch_encode_plus(df_test.full_sent.values, add_special_tokens=True, 
                                               return_attention_mask=True, pad_to_max_length=True, max_length=256, return_tensors='pt')
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2142: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
""" access the data train dictionary and pull out the input ids which essetntailly represents each word as a number"""
input_ids_train=encoded_data_train['input_ids']
attention_masks_train=encoded_data_train['attention_mask']
#make a tensor out of the original data labels
labels_train=torch.tensor(df_train.label.values, dtype=torch.long)

# %% [markdown]
# ####We create the train data set by TensorDataset which used in pytorch library.

# %%
#iterates over each three element at one time for each data set
dataset_train=TensorDataset(input_ids_train,
                            attention_masks_train,labels_train)

# %%
#repeat for test set
input_ids_test=encoded_data_test['input_ids']
attention_masks_test=encoded_data_test['attention_mask']
labels_test=torch.tensor(df_test.label.values, dtype=torch.long)

# %%
dataset_test=TensorDataset(input_ids_test,
                            attention_masks_test,labels_test)

# %%
print(len(dataset_train))
print(len(dataset_test))
# Out:
# 15752
# 4490

# %% [markdown]
# ####We import the pretrained BERT model from module Huggingface's transformer library.

# %%
from transformers import BertForSequenceClassification

# %% [markdown]
# ####In this part we can as well fine tune the pretrained BERT by outlining number of labels the final layer of BERT should have. We add a layer on top of that of size 19 as a classifier.

# %%
model= BertForSequenceClassification.from_pretrained(
                'bert-base-uncased',
                #length of the label dictionary is 19
                 num_labels=19, 
                  output_attentions=False, 
                  #the state before the output state which won't be needed to return
                 output_hidden_states=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ####Dataloaders make it possible to iterate over the dataset in batches. Randomsampler samples the data randomly per batch. This will help randomize what data the model is exposed to. Sequential sampler can be used for test set, as for test set randomly sorting the data set is not as important as the gradients are fixed already in that stage.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
batch_size=32 
dataloader_train=DataLoader(dataset_train, 
                            sampler=RandomSampler(dataset_train), 
                            batch_size=batch_size)

# %%
dataloader_test=DataLoader(dataset_test, 
                            sampler=RandomSampler(dataset_test), 
                            batch_size=batch_size)

# %% [markdown]
# ####Setting the optimizer to Adam as a stochastic optimizer.

# %%
from transformers import AdamW, get_linear_schedule_with_warmup

# %%
optimizer=AdamW(
    model.parameters(), 
    lr=1e-5, #2e-5 >5e-5
    eps=1e-8
)

# %%
epochs=10
scheduler=get_linear_schedule_with_warmup(
    optimizer, 
    num_warmup_steps=0, 
    #how many times learning rate is set to change
    num_training_steps=len(dataloader_train)*epochs
)

# %%
import numpy as np

# %%
from sklearn.metrics import f1_score

# %% [markdown]
# ####Predictions will come in the foramt of probabilities turned into 0s and 1s.

# %%
#preds=[0.9, 0.07, 0.05]--> #preds=[1, 0, 0]
def f1_score_func(preds, labels):
  preds_flat=np.argmax(preds, axis=1).flatten()
  labels_flat=labels.flatten()
  return f1_score(labels_flat, preds_flat, average='weighted')

# %%
def accuracy_per_class(preds, labels):
  label_dict_inverse={v: k for k, v in label_dict.items()}

  preds_flat=np.argmax(preds, axis=1).flatten()
  labels_flat=labels.flatten()

  for label in np.unique(labels_flat):
    y_preds=preds_flat[labels_flat==label]
    y_true=labels_flat[labels_flat==label]
    print(f'Class:{label_dict_inverse[label]}')
    print(f'Accuracy:{len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
import random
seed_val=17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#send the model to the available device
model.to(device)
print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_test):
  model.eval()

  loss_test_total=0
  predictions, true_vals=[],[]
  
  for batch in dataloader_test:
      batch=tuple(b.to(device) for b in batch)

      inputs={
          'input_ids': batch[0],

          'attention_mask': batch[1],
          'labels': batch[2]

      }
      with torch.no_grad():
        outputs=model(**inputs)

      loss=outputs[0]
      logits= outputs[1]
      loss_test_total +=loss.item()
      #loss.backward()

      logits=logits.detach().cpu().numpy()
      label_ids=inputs['labels'].cpu().numpy()
      predictions.append(logits)
      true_vals.append(label_ids)



      
  loss_test_avg=loss_test_total/len(dataloader_test)

  predictions=np.concatenate(predictions, axis=0)
  true_vals=np.concatenate(true_vals, axis=0)


  return loss_test_avg, predictions, true_vals

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %%
from tqdm import tqdm

# %%
for  epoch in tqdm(range(1, epochs+1)):  
  
  model.train()

  loss_train_total=0

  progress_bar=tqdm(dataloader_train, 
                    desc='Epoch {:1d}'.format(epoch), 
                    leave=False, 
                    disable=False)
                    
  for batch in progress_bar:
      model.zero_grad()
      batch=tuple(b.to(device) for b in batch)
      inputs={
          'input_ids': batch[0],

          'attention_mask': batch[1],
          'labels': batch[2]

      }
      #with torch.no_grad():
      outputs=model(**inputs)

      loss=outputs[0]
      loss_train_total +=loss.item()
      loss.backward()



      torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
      optimizer.step()
      scheduler.step()
      progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch) )})
  torch.save(model.state_dict(), f'/content/BERT_ft_epoch{epoch}.model')
  tqdm.write('\nEpoch {epoch}')
  loss_train_avg=loss_train_total/len(dataloader_train)
  tqdm.write(f'Training loss:{loss_train_avg}')
  val_loss, predictions, true_vals=evaluate(dataloader_test)

  val_f1=f1_score_func(predictions, true_vals)
  tqdm.write(f'Validation loss: {val_loss}')
  tqdm.write(f'F1 Score (weighted): {val_f1}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Epoch 1:   0%|          | 0/493 [00:00<?, ?it/s]
#
# Epoch 1:   0%|          | 0/493 [00:00<?, ?it/s, training_loss=0.226]
#
# Epoch 1:   0%|          | 1/493 [00:00<03:52,  2.12it/s, training_loss=0.226]
#
# Epoch 1:   0%|          | 1/493 [00:00<03:52,  2.12it/s, training_loss=0.263]
#
# Epoch 1:   0%|          | 2/493 [00:00<03:48,  2.15it/s, training_loss=0.263]
#
# Epoch 1:   0%|          | 2/493 [00:01<03:48,  2.15it/s, training_loss=0.193]
#
# Epoch 1:   1%|          | 3/493 [00:01<03:46,  2.17it/s, training_loss=0.193]
#
# Epoch 1:   1%|          | 3/493 [00:01<03:46,  2.17it/s, training_loss=0.188]
#
# Epoch 1:   1%|          | 4/493 [00:01<03:43,  2.19it/s, training_loss=0.188]
#
# Epoch 1:   1%|          | 4/493 [00:02<03:43,  2.19it/s, training_loss=0.112]
#
# Epoch 1:   1%|          | 5/493 [00:02<03:41,  2.20it/s, training_loss=0.112]
#
# Epoch 1:   1%|          | 5/493 [00:02<03:41,  2.20it/s, training_loss=0.234]
#
# Epoch 1:   1%|          | 6/493 [00:02<03:40,  2.21it/s, training_loss=0.234]
#
# Epoch 1:   1%|          | 6/493 [00:03<03:40,  2.21it/s, training_loss=0.222]
#
# Epoch 1:   1%|▏         | 7/493 [00:03<03:39,  2.22it/s, training_loss=0.222]
#
# Epoch 1:   1%|▏         | 7/493 [00:03<03:39,  2.22it/s, training_loss=0.292]
#
# Epoch 1:   2%|▏         | 8/493 [00:03<03:38,  2.22it/s, training_loss=0.292]
#
# Epoch 1:   2%|▏         | 8/493 [00:04<03:38,  2.22it/s, training_loss=0.078]
#
# Epoch 1:   2%|▏         | 9/493 [00:04<03:37,  2.22it/s, training_loss=0.078]
#
# Epoch 1:   2%|▏         | 9/493 [00:04<03:37,  2.22it/s, training_loss=0.194]
#
# Epoch 1:   2%|▏         | 10/493 [00:04<03:37,  2.22it/s, training_loss=0.194]
#
# Epoch 1:   2%|▏         | 10/493 [00:04<03:37,  2.22it/s, training_loss=0.215]
#
# Epoch 1:   2%|▏         | 11/493 [00:04<03:38,  2.21it/s, training_loss=0.215]
#
# Epoch 1:   2%|▏         | 11/493 [00:05<03:38,  2.21it/s, training_loss=0.182]
#
# Epoch 1:   2%|▏         | 12/493 [00:05<03:37,  2.21it/s, training_loss=0.182]
#
# Epoch 1:   2%|▏         | 12/493 [00:05<03:37,  2.21it/s, training_loss=0.238]
#
# Epoch 1:   3%|▎         | 13/493 [00:05<03:36,  2.21it/s, training_loss=0.238]
#
# Epoch 1:   3%|▎         | 13/493 [00:06<03:36,  2.21it/s, training_loss=0.199]
#
# Epoch 1:   3%|▎         | 14/493 [00:06<03:37,  2.20it/s, training_loss=0.199]
#
# Epoch 1:   3%|▎         | 14/493 [00:06<03:37,  2.20it/s, training_loss=0.193]
#
# Epoch 1:   3%|▎         | 15/493 [00:06<03:37,  2.20it/s, training_loss=0.193]
#
# Epoch 1:   3%|▎         | 15/493 [00:07<03:37,  2.20it/s, training_loss=0.178]
#
# Epoch 1:   3%|▎         | 16/493 [00:07<03:43,  2.13it/s, training_loss=0.178]
#
# Epoch 1:   3%|▎         | 16/493 [00:07<03:43,  2.13it/s, training_loss=0.286]
#
# Epoch 1:   3%|▎         | 17/493 [00:07<03:48,  2.09it/s, training_loss=0.286]
#
# Epoch 1:   3%|▎         | 17/493 [00:08<03:48,  2.09it/s, training_loss=0.432]
#
# Epoch 1:   4%|▎         | 18/493 [00:08<03:51,  2.05it/s, training_loss=0.432]
#
# Epoch 1:   4%|▎         | 18/493 [00:08<03:51,  2.05it/s, training_loss=0.227]
#
# Epoch 1:   4%|▍         | 19/493 [00:08<03:53,  2.03it/s, training_loss=0.227]
#
# Epoch 1:   4%|▍         | 19/493 [00:09<03:53,  2.03it/s, training_loss=0.309]
#
# Epoch 1:   4%|▍         | 20/493 [00:09<03:54,  2.01it/s, training_loss=0.309]
#
# Epoch 1:   4%|▍         | 20/493 [00:09<03:54,  2.01it/s, training_loss=0.138]
#
# Epoch 1:   4%|▍         | 21/493 [00:09<03:56,  2.00it/s, training_loss=0.138]
#
# Epoch 1:   4%|▍         | 21/493 [00:10<03:56,  2.00it/s, training_loss=0.198]
#
# Epoch 1:   4%|▍         | 22/493 [00:10<03:57,  1.99it/s, training_loss=0.198]
#
# Epoch 1:   4%|▍         | 22/493 [00:10<03:57,  1.99it/s, training_loss=0.126]
#
# Epoch 1:   5%|▍         | 23/493 [00:10<03:52,  2.02it/s, training_loss=0.126]
#
# Epoch 1:   5%|▍         | 23/493 [00:11<03:52,  2.02it/s, training_loss=0.268]
#
# Epoch 1:   5%|▍         | 24/493 [00:11<03:45,  2.08it/s, training_loss=0.268]
#
# Epoch 1:   5%|▍         | 24/493 [00:11<03:45,  2.08it/s, training_loss=0.163]
#
# Epoch 1:   5%|▌         | 25/493 [00:11<03:40,  2.12it/s, training_loss=0.163]
#
# Epoch 1:   5%|▌         | 25/493 [00:12<03:40,  2.12it/s, training_loss=0.239]
#
# Epoch 1:   5%|▌         | 26/493 [00:12<03:37,  2.15it/s, training_loss=0.239]
#
# Epoch 1:   5%|▌         | 26/493 [00:12<03:37,  2.15it/s, training_loss=0.186]
#
# Epoch 1:   5%|▌         | 27/493 [00:12<03:34,  2.18it/s, training_loss=0.186]
#
# Epoch 1:   5%|▌         | 27/493 [00:13<03:34,  2.18it/s, training_loss=0.209]
#
# Epoch 1:   6%|▌         | 28/493 [00:13<03:33,  2.18it/s, training_loss=0.209]
#
# Epoch 1:   6%|▌         | 28/493 [00:13<03:33,  2.18it/s, training_loss=0.169]
#
# Epoch 1:   6%|▌         | 29/493 [00:13<03:31,  2.19it/s, training_loss=0.169]
#
# Epoch 1:   6%|▌         | 29/493 [00:13<03:31,  2.19it/s, training_loss=0.203]
#
# Epoch 1:   6%|▌         | 30/493 [00:13<03:30,  2.20it/s, training_loss=0.203]
#
# Epoch 1:   6%|▌         | 30/493 [00:14<03:30,  2.20it/s, training_loss=0.162]
#
# Epoch 1:   6%|▋         | 31/493 [00:14<03:29,  2.21it/s, training_loss=0.162]
#
# Epoch 1:   6%|▋         | 31/493 [00:14<03:29,  2.21it/s, training_loss=0.074]
#
# Epoch 1:   6%|▋         | 32/493 [00:14<03:28,  2.21it/s, training_loss=0.074]
#
# Epoch 1:   6%|▋         | 32/493 [00:15<03:28,  2.21it/s, training_loss=0.188]
#
# Epoch 1:   7%|▋         | 33/493 [00:15<03:28,  2.20it/s, training_loss=0.188]
#
# Epoch 1:   7%|▋         | 33/493 [00:15<03:28,  2.20it/s, training_loss=0.214]
#
# Epoch 1:   7%|▋         | 34/493 [00:15<03:29,  2.19it/s, training_loss=0.214]
#
# Epoch 1:   7%|▋         | 34/493 [00:16<03:29,  2.19it/s, training_loss=0.239]
#
# Epoch 1:   7%|▋         | 35/493 [00:16<03:28,  2.20it/s, training_loss=0.239]
#
# Epoch 1:   7%|▋         | 35/493 [00:16<03:28,  2.20it/s, training_loss=0.263]
#
# Epoch 1:   7%|▋         | 36/493 [00:16<03:27,  2.20it/s, training_loss=0.263]
#
# Epoch 1:   7%|▋         | 36/493 [00:17<03:27,  2.20it/s, training_loss=0.138]
#
# Epoch 1:   8%|▊         | 37/493 [00:17<03:26,  2.21it/s, training_loss=0.138]
#
# Epoch 1:   8%|▊         | 37/493 [00:17<03:26,  2.21it/s, training_loss=0.253]
#
# Epoch 1:   8%|▊         | 38/493 [00:17<03:25,  2.21it/s, training_loss=0.253]
#
# Epoch 1:   8%|▊         | 38/493 [00:18<03:25,  2.21it/s, training_loss=0.157]
#
# Epoch 1:   8%|▊         | 39/493 [00:18<03:25,  2.21it/s, training_loss=0.157]
#
# Epoch 1:   8%|▊         | 39/493 [00:18<03:25,  2.21it/s, training_loss=0.207]
#
# Epoch 1:   8%|▊         | 40/493 [00:18<03:25,  2.20it/s, training_loss=0.207]
#
# Epoch 1:   8%|▊         | 40/493 [00:18<03:25,  2.20it/s, training_loss=0.272]
#
# Epoch 1:   8%|▊         | 41/493 [00:18<03:24,  2.21it/s, training_loss=0.272]
#
# Epoch 1:   8%|▊         | 41/493 [00:19<03:24,  2.21it/s, training_loss=0.300]
#
# Epoch 1:   9%|▊         | 42/493 [00:19<03:23,  2.21it/s, training_loss=0.300]
#
# Epoch 1:   9%|▊         | 42/493 [00:19<03:23,  2.21it/s, training_loss=0.132]
#
# Epoch 1:   9%|▊         | 43/493 [00:19<03:23,  2.21it/s, training_loss=0.132]
#
# Epoch 1:   9%|▊         | 43/493 [00:20<03:23,  2.21it/s, training_loss=0.121]
#
# Epoch 1:   9%|▉         | 44/493 [00:20<03:22,  2.22it/s, training_loss=0.121]
#
# Epoch 1:   9%|▉         | 44/493 [00:20<03:22,  2.22it/s, training_loss=0.181]
#
# Epoch 1:   9%|▉         | 45/493 [00:20<03:21,  2.22it/s, training_loss=0.181]
#
# Epoch 1:   9%|▉         | 45/493 [00:21<03:21,  2.22it/s, training_loss=0.212]
#
# Epoch 1:   9%|▉         | 46/493 [00:21<03:20,  2.22it/s, training_loss=0.212]
#
# Epoch 1:   9%|▉         | 46/493 [00:21<03:20,  2.22it/s, training_loss=0.341]
#
# Epoch 1:  10%|▉         | 47/493 [00:21<03:20,  2.23it/s, training_loss=0.341]
#
# Epoch 1:  10%|▉         | 47/493 [00:22<03:20,  2.23it/s, training_loss=0.167]
#
# Epoch 1:  10%|▉         | 48/493 [00:22<03:19,  2.23it/s, training_loss=0.167]
#
# Epoch 1:  10%|▉         | 48/493 [00:22<03:19,  2.23it/s, training_loss=0.177]
#
# Epoch 1:  10%|▉         | 49/493 [00:22<03:19,  2.22it/s, training_loss=0.177]
#
# Epoch 1:  10%|▉         | 49/493 [00:22<03:19,  2.22it/s, training_loss=0.214]
#
# Epoch 1:  10%|█         | 50/493 [00:22<03:19,  2.22it/s, training_loss=0.214]
#
# Epoch 1:  10%|█         | 50/493 [00:23<03:19,  2.22it/s, training_loss=0.109]
#
# Epoch 1:  10%|█         | 51/493 [00:23<03:18,  2.22it/s, training_loss=0.109]
#
# Epoch 1:  10%|█         | 51/493 [00:23<03:18,  2.22it/s, training_loss=0.132]
#
# Epoch 1:  11%|█         | 52/493 [00:23<03:19,  2.21it/s, training_loss=0.132]
#
# Epoch 1:  11%|█         | 52/493 [00:24<03:19,  2.21it/s, training_loss=0.205]
#
# Epoch 1:  11%|█         | 53/493 [00:24<03:18,  2.21it/s, training_loss=0.205]
#
# Epoch 1:  11%|█         | 53/493 [00:24<03:18,  2.21it/s, training_loss=0.173]
#
# Epoch 1:  11%|█         | 54/493 [00:24<03:17,  2.22it/s, training_loss=0.173]
#
# Epoch 1:  11%|█         | 54/493 [00:25<03:17,  2.22it/s, training_loss=0.242]
#
# Epoch 1:  11%|█         | 55/493 [00:25<03:17,  2.22it/s, training_loss=0.242]
#
# Epoch 1:  11%|█         | 55/493 [00:25<03:17,  2.22it/s, training_loss=0.201]
#
# Epoch 1:  11%|█▏        | 56/493 [00:25<03:16,  2.22it/s, training_loss=0.201]
#
# Epoch 1:  11%|█▏        | 56/493 [00:26<03:16,  2.22it/s, training_loss=0.231]
#
# Epoch 1:  12%|█▏        | 57/493 [00:26<03:16,  2.22it/s, training_loss=0.231]
#
# Epoch 1:  12%|█▏        | 57/493 [00:26<03:16,  2.22it/s, training_loss=0.238]
#
# Epoch 1:  12%|█▏        | 58/493 [00:26<03:15,  2.23it/s, training_loss=0.238]
#
# Epoch 1:  12%|█▏        | 58/493 [00:27<03:15,  2.23it/s, training_loss=0.184]
#
# Epoch 1:  12%|█▏        | 59/493 [00:27<03:15,  2.22it/s, training_loss=0.184]
#
# Epoch 1:  12%|█▏        | 59/493 [00:27<03:15,  2.22it/s, training_loss=0.168]
#
# Epoch 1:  12%|█▏        | 60/493 [00:27<03:16,  2.21it/s, training_loss=0.168]
#
# Epoch 1:  12%|█▏        | 60/493 [00:27<03:16,  2.21it/s, training_loss=0.199]
#
# Epoch 1:  12%|█▏        | 61/493 [00:27<03:17,  2.19it/s, training_loss=0.199]
#
# Epoch 1:  12%|█▏        | 61/493 [00:28<03:17,  2.19it/s, training_loss=0.334]
#
# Epoch 1:  13%|█▎        | 62/493 [00:28<03:16,  2.20it/s, training_loss=0.334]
#
# Epoch 1:  13%|█▎        | 62/493 [00:28<03:16,  2.20it/s, training_loss=0.145]
#
# Epoch 1:  13%|█▎        | 63/493 [00:28<03:15,  2.20it/s, training_loss=0.145]
#
# Epoch 1:  13%|█▎        | 63/493 [00:29<03:15,  2.20it/s, training_loss=0.151]
#
# Epoch 1:  13%|█▎        | 64/493 [00:29<03:13,  2.21it/s, training_loss=0.151]
#
# Epoch 1:  13%|█▎        | 64/493 [00:29<03:13,  2.21it/s, training_loss=0.091]
#
# Epoch 1:  13%|█▎        | 65/493 [00:29<03:13,  2.21it/s, training_loss=0.091]
#
# Epoch 1:  13%|█▎        | 65/493 [00:30<03:13,  2.21it/s, training_loss=0.194]
#
# Epoch 1:  13%|█▎        | 66/493 [00:30<03:12,  2.21it/s, training_loss=0.194]
#
# Epoch 1:  13%|█▎        | 66/493 [00:30<03:12,  2.21it/s, training_loss=0.163]
#
# Epoch 1:  14%|█▎        | 67/493 [00:30<03:12,  2.22it/s, training_loss=0.163]
#
# Epoch 1:  14%|█▎        | 67/493 [00:31<03:12,  2.22it/s, training_loss=0.222]
#
# Epoch 1:  14%|█▍        | 68/493 [00:31<03:13,  2.20it/s, training_loss=0.222]
#
# Epoch 1:  14%|█▍        | 68/493 [00:31<03:13,  2.20it/s, training_loss=0.234]
#
# Epoch 1:  14%|█▍        | 69/493 [00:31<03:12,  2.20it/s, training_loss=0.234]
#
# Epoch 1:  14%|█▍        | 69/493 [00:32<03:12,  2.20it/s, training_loss=0.299]
#
# Epoch 1:  14%|█▍        | 70/493 [00:32<03:11,  2.21it/s, training_loss=0.299]
#
# Epoch 1:  14%|█▍        | 70/493 [00:32<03:11,  2.21it/s, training_loss=0.247]
#
# Epoch 1:  14%|█▍        | 71/493 [00:32<03:10,  2.22it/s, training_loss=0.247]
#
# Epoch 1:  14%|█▍        | 71/493 [00:32<03:10,  2.22it/s, training_loss=0.196]
#
# Epoch 1:  15%|█▍        | 72/493 [00:32<03:09,  2.22it/s, training_loss=0.196]
#
# Epoch 1:  15%|█▍        | 72/493 [00:33<03:09,  2.22it/s, training_loss=0.269]
#
# Epoch 1:  15%|█▍        | 73/493 [00:33<03:09,  2.21it/s, training_loss=0.269]
#
# Epoch 1:  15%|█▍        | 73/493 [00:33<03:09,  2.21it/s, training_loss=0.139]
#
# Epoch 1:  15%|█▌        | 74/493 [00:33<03:09,  2.21it/s, training_loss=0.139]
#
# Epoch 1:  15%|█▌        | 74/493 [00:34<03:09,  2.21it/s, training_loss=0.286]
#
# Epoch 1:  15%|█▌        | 75/493 [00:34<03:08,  2.22it/s, training_loss=0.286]
#
# Epoch 1:  15%|█▌        | 75/493 [00:34<03:08,  2.22it/s, training_loss=0.195]
#
# Epoch 1:  15%|█▌        | 76/493 [00:34<03:08,  2.21it/s, training_loss=0.195]
#
# Epoch 1:  15%|█▌        | 76/493 [00:35<03:08,  2.21it/s, training_loss=0.225]
#
# Epoch 1:  16%|█▌        | 77/493 [00:35<03:07,  2.21it/s, training_loss=0.225]
#
# Epoch 1:  16%|█▌        | 77/493 [00:35<03:07,  2.21it/s, training_loss=0.123]
#
# Epoch 1:  16%|█▌        | 78/493 [00:35<03:07,  2.22it/s, training_loss=0.123]
#
# Epoch 1:  16%|█▌        | 78/493 [00:36<03:07,  2.22it/s, training_loss=0.113]
#
# Epoch 1:  16%|█▌        | 79/493 [00:36<03:06,  2.22it/s, training_loss=0.113]
#
# Epoch 1:  16%|█▌        | 79/493 [00:36<03:06,  2.22it/s, training_loss=0.200]
#
# Epoch 1:  16%|█▌        | 80/493 [00:36<03:06,  2.22it/s, training_loss=0.200]
#
# Epoch 1:  16%|█▌        | 80/493 [00:37<03:06,  2.22it/s, training_loss=0.281]
#
# Epoch 1:  16%|█▋        | 81/493 [00:37<03:05,  2.22it/s, training_loss=0.281]
#
# Epoch 1:  16%|█▋        | 81/493 [00:37<03:05,  2.22it/s, training_loss=0.237]
#
# Epoch 1:  17%|█▋        | 82/493 [00:37<03:05,  2.22it/s, training_loss=0.237]
#
# Epoch 1:  17%|█▋        | 82/493 [00:37<03:05,  2.22it/s, training_loss=0.179]
#
# Epoch 1:  17%|█▋        | 83/493 [00:37<03:04,  2.22it/s, training_loss=0.179]
#
# Epoch 1:  17%|█▋        | 83/493 [00:38<03:04,  2.22it/s, training_loss=0.235]
#
# Epoch 1:  17%|█▋        | 84/493 [00:38<03:05,  2.20it/s, training_loss=0.235]
#
# Epoch 1:  17%|█▋        | 84/493 [00:38<03:05,  2.20it/s, training_loss=0.246]
#
# Epoch 1:  17%|█▋        | 85/493 [00:38<03:05,  2.20it/s, training_loss=0.246]
#
# Epoch 1:  17%|█▋        | 85/493 [00:39<03:05,  2.20it/s, training_loss=0.188]
#
# Epoch 1:  17%|█▋        | 86/493 [00:39<03:05,  2.19it/s, training_loss=0.188]
#
# Epoch 1:  17%|█▋        | 86/493 [00:39<03:05,  2.19it/s, training_loss=0.182]
#
# Epoch 1:  18%|█▊        | 87/493 [00:39<03:06,  2.18it/s, training_loss=0.182]
#
# Epoch 1:  18%|█▊        | 87/493 [00:40<03:06,  2.18it/s, training_loss=0.177]
#
# Epoch 1:  18%|█▊        | 88/493 [00:40<03:06,  2.17it/s, training_loss=0.177]
#
# Epoch 1:  18%|█▊        | 88/493 [00:40<03:06,  2.17it/s, training_loss=0.180]
#
# Epoch 1:  18%|█▊        | 89/493 [00:40<03:04,  2.18it/s, training_loss=0.180]
#
# Epoch 1:  18%|█▊        | 89/493 [00:41<03:04,  2.18it/s, training_loss=0.240]
#
# Epoch 1:  18%|█▊        | 90/493 [00:41<03:03,  2.19it/s, training_loss=0.240]
#
# Epoch 1:  18%|█▊        | 90/493 [00:41<03:03,  2.19it/s, training_loss=0.213]
#
# Epoch 1:  18%|█▊        | 91/493 [00:41<03:04,  2.18it/s, training_loss=0.213]
#
# Epoch 1:  18%|█▊        | 91/493 [00:42<03:04,  2.18it/s, training_loss=0.220]
#
# Epoch 1:  19%|█▊        | 92/493 [00:42<03:04,  2.18it/s, training_loss=0.220]
#
# Epoch 1:  19%|█▊        | 92/493 [00:42<03:04,  2.18it/s, training_loss=0.176]
#
# Epoch 1:  19%|█▉        | 93/493 [00:42<03:02,  2.19it/s, training_loss=0.176]
#
# Epoch 1:  19%|█▉        | 93/493 [00:42<03:02,  2.19it/s, training_loss=0.191]
#
# Epoch 1:  19%|█▉        | 94/493 [00:42<03:01,  2.19it/s, training_loss=0.191]
#
# Epoch 1:  19%|█▉        | 94/493 [00:43<03:01,  2.19it/s, training_loss=0.318]
#
# Epoch 1:  19%|█▉        | 95/493 [00:43<03:01,  2.20it/s, training_loss=0.318]
#
# Epoch 1:  19%|█▉        | 95/493 [00:43<03:01,  2.20it/s, training_loss=0.277]
#
# Epoch 1:  19%|█▉        | 96/493 [00:43<03:00,  2.20it/s, training_loss=0.277]
#
# Epoch 1:  19%|█▉        | 96/493 [00:44<03:00,  2.20it/s, training_loss=0.279]
#
# Epoch 1:  20%|█▉        | 97/493 [00:44<02:59,  2.21it/s, training_loss=0.279]
#
# Epoch 1:  20%|█▉        | 97/493 [00:44<02:59,  2.21it/s, training_loss=0.346]
#
# Epoch 1:  20%|█▉        | 98/493 [00:44<02:58,  2.22it/s, training_loss=0.346]
#
# Epoch 1:  20%|█▉        | 98/493 [00:45<02:58,  2.22it/s, training_loss=0.193]
#
# Epoch 1:  20%|██        | 99/493 [00:45<02:57,  2.22it/s, training_loss=0.193]
#
# Epoch 1:  20%|██        | 99/493 [00:45<02:57,  2.22it/s, training_loss=0.234]
#
# Epoch 1:  20%|██        | 100/493 [00:45<02:57,  2.22it/s, training_loss=0.234]
#
# Epoch 1:  20%|██        | 100/493 [00:46<02:57,  2.22it/s, training_loss=0.190]
#
# Epoch 1:  20%|██        | 101/493 [00:46<02:57,  2.21it/s, training_loss=0.190]
#
# Epoch 1:  20%|██        | 101/493 [00:46<02:57,  2.21it/s, training_loss=0.128]
#
# Epoch 1:  21%|██        | 102/493 [00:46<02:56,  2.21it/s, training_loss=0.128]
#
# Epoch 1:  21%|██        | 102/493 [00:47<02:56,  2.21it/s, training_loss=0.251]
#
# Epoch 1:  21%|██        | 103/493 [00:47<02:56,  2.21it/s, training_loss=0.251]
#
# Epoch 1:  21%|██        | 103/493 [00:47<02:56,  2.21it/s, training_loss=0.198]
#
# Epoch 1:  21%|██        | 104/493 [00:47<02:57,  2.19it/s, training_loss=0.198]
#
# Epoch 1:  21%|██        | 104/493 [00:47<02:57,  2.19it/s, training_loss=0.183]
#
# Epoch 1:  21%|██▏       | 105/493 [00:47<02:56,  2.20it/s, training_loss=0.183]
#
# Epoch 1:  21%|██▏       | 105/493 [00:48<02:56,  2.20it/s, training_loss=0.174]
#
# Epoch 1:  22%|██▏       | 106/493 [00:48<02:55,  2.20it/s, training_loss=0.174]
#
# Epoch 1:  22%|██▏       | 106/493 [00:48<02:55,  2.20it/s, training_loss=0.144]
#
# Epoch 1:  22%|██▏       | 107/493 [00:48<02:56,  2.19it/s, training_loss=0.144]
#
# Epoch 1:  22%|██▏       | 107/493 [00:49<02:56,  2.19it/s, training_loss=0.195]
#
# Epoch 1:  22%|██▏       | 108/493 [00:49<02:55,  2.19it/s, training_loss=0.195]
#
# Epoch 1:  22%|██▏       | 108/493 [00:49<02:55,  2.19it/s, training_loss=0.357]
#
# Epoch 1:  22%|██▏       | 109/493 [00:49<02:54,  2.20it/s, training_loss=0.357]
#
# Epoch 1:  22%|██▏       | 109/493 [00:50<02:54,  2.20it/s, training_loss=0.274]
#
# Epoch 1:  22%|██▏       | 110/493 [00:50<02:54,  2.20it/s, training_loss=0.274]
#
# Epoch 1:  22%|██▏       | 110/493 [00:50<02:54,  2.20it/s, training_loss=0.133]
#
# Epoch 1:  23%|██▎       | 111/493 [00:50<02:53,  2.20it/s, training_loss=0.133]
#
# Epoch 1:  23%|██▎       | 111/493 [00:51<02:53,  2.20it/s, training_loss=0.256]
#
# Epoch 1:  23%|██▎       | 112/493 [00:51<02:53,  2.20it/s, training_loss=0.256]
#
# Epoch 1:  23%|██▎       | 112/493 [00:51<02:53,  2.20it/s, training_loss=0.249]
#
# Epoch 1:  23%|██▎       | 113/493 [00:51<02:52,  2.20it/s, training_loss=0.249]
#
# Epoch 1:  23%|██▎       | 113/493 [00:52<02:52,  2.20it/s, training_loss=0.193]
#
# Epoch 1:  23%|██▎       | 114/493 [00:52<02:52,  2.19it/s, training_loss=0.193]
#
# Epoch 1:  23%|██▎       | 114/493 [00:52<02:52,  2.19it/s, training_loss=0.275]
#
# Epoch 1:  23%|██▎       | 115/493 [00:52<02:52,  2.19it/s, training_loss=0.275]
#
# Epoch 1:  23%|██▎       | 115/493 [00:52<02:52,  2.19it/s, training_loss=0.256]
#
# Epoch 1:  24%|██▎       | 116/493 [00:52<02:51,  2.20it/s, training_loss=0.256]
#
# Epoch 1:  24%|██▎       | 116/493 [00:53<02:51,  2.20it/s, training_loss=0.241]
#
# Epoch 1:  24%|██▎       | 117/493 [00:53<02:51,  2.20it/s, training_loss=0.241]
#
# Epoch 1:  24%|██▎       | 117/493 [00:53<02:51,  2.20it/s, training_loss=0.137]
#
# Epoch 1:  24%|██▍       | 118/493 [00:53<02:50,  2.20it/s, training_loss=0.137]
#
# Epoch 1:  24%|██▍       | 118/493 [00:54<02:50,  2.20it/s, training_loss=0.490]
#
# Epoch 1:  24%|██▍       | 119/493 [00:54<02:49,  2.21it/s, training_loss=0.490]
#
# Epoch 1:  24%|██▍       | 119/493 [00:54<02:49,  2.21it/s, training_loss=0.252]
#
# Epoch 1:  24%|██▍       | 120/493 [00:54<02:48,  2.21it/s, training_loss=0.252]
#
# Epoch 1:  24%|██▍       | 120/493 [00:55<02:48,  2.21it/s, training_loss=0.268]
#
# Epoch 1:  25%|██▍       | 121/493 [00:55<02:48,  2.20it/s, training_loss=0.268]
#
# Epoch 1:  25%|██▍       | 121/493 [00:55<02:48,  2.20it/s, training_loss=0.144]
#
# Epoch 1:  25%|██▍       | 122/493 [00:55<02:48,  2.20it/s, training_loss=0.144]
#
# Epoch 1:  25%|██▍       | 122/493 [00:56<02:48,  2.20it/s, training_loss=0.202]
#
# Epoch 1:  25%|██▍       | 123/493 [00:56<02:48,  2.20it/s, training_loss=0.202]
#
# Epoch 1:  25%|██▍       | 123/493 [00:56<02:48,  2.20it/s, training_loss=0.166]
#
# Epoch 1:  25%|██▌       | 124/493 [00:56<02:49,  2.18it/s, training_loss=0.166]
#
# Epoch 1:  25%|██▌       | 124/493 [00:57<02:49,  2.18it/s, training_loss=0.308]
#
# Epoch 1:  25%|██▌       | 125/493 [00:57<02:48,  2.18it/s, training_loss=0.308]
#
# Epoch 1:  25%|██▌       | 125/493 [00:57<02:48,  2.18it/s, training_loss=0.210]
#
# Epoch 1:  26%|██▌       | 126/493 [00:57<02:47,  2.19it/s, training_loss=0.210]
#
# Epoch 1:  26%|██▌       | 126/493 [00:57<02:47,  2.19it/s, training_loss=0.152]
#
# Epoch 1:  26%|██▌       | 127/493 [00:57<02:46,  2.20it/s, training_loss=0.152]
#
# Epoch 1:  26%|██▌       | 127/493 [00:58<02:46,  2.20it/s, training_loss=0.166]
#
# Epoch 1:  26%|██▌       | 128/493 [00:58<02:46,  2.20it/s, training_loss=0.166]
#
# Epoch 1:  26%|██▌       | 128/493 [00:58<02:46,  2.20it/s, training_loss=0.186]
#
# Epoch 1:  26%|██▌       | 129/493 [00:58<02:45,  2.20it/s, training_loss=0.186]
#
# Epoch 1:  26%|██▌       | 129/493 [00:59<02:45,  2.20it/s, training_loss=0.301]
#
# Epoch 1:  26%|██▋       | 130/493 [00:59<02:44,  2.20it/s, training_loss=0.301]
#
# Epoch 1:  26%|██▋       | 130/493 [00:59<02:44,  2.20it/s, training_loss=0.204]
#
# Epoch 1:  27%|██▋       | 131/493 [00:59<02:45,  2.19it/s, training_loss=0.204]
#
# Epoch 1:  27%|██▋       | 131/493 [01:00<02:45,  2.19it/s, training_loss=0.294]
#
# Epoch 1:  27%|██▋       | 132/493 [01:00<02:44,  2.20it/s, training_loss=0.294]
#
# Epoch 1:  27%|██▋       | 132/493 [01:00<02:44,  2.20it/s, training_loss=0.194]
#
# Epoch 1:  27%|██▋       | 133/493 [01:00<02:43,  2.20it/s, training_loss=0.194]
#
# Epoch 1:  27%|██▋       | 133/493 [01:01<02:43,  2.20it/s, training_loss=0.271]
#
# Epoch 1:  27%|██▋       | 134/493 [01:01<02:42,  2.21it/s, training_loss=0.271]
#
# Epoch 1:  27%|██▋       | 134/493 [01:01<02:42,  2.21it/s, training_loss=0.263]
#
# Epoch 1:  27%|██▋       | 135/493 [01:01<02:42,  2.20it/s, training_loss=0.263]
#
# Epoch 1:  27%|██▋       | 135/493 [01:02<02:42,  2.20it/s, training_loss=0.172]
#
# Epoch 1:  28%|██▊       | 136/493 [01:02<02:42,  2.20it/s, training_loss=0.172]
#
# Epoch 1:  28%|██▊       | 136/493 [01:02<02:42,  2.20it/s, training_loss=0.362]
#
# Epoch 1:  28%|██▊       | 137/493 [01:02<02:41,  2.21it/s, training_loss=0.362]
#
# Epoch 1:  28%|██▊       | 137/493 [01:02<02:41,  2.21it/s, training_loss=0.267]
#
# Epoch 1:  28%|██▊       | 138/493 [01:02<02:40,  2.21it/s, training_loss=0.267]
#
# Epoch 1:  28%|██▊       | 138/493 [01:03<02:40,  2.21it/s, training_loss=0.167]
#
# Epoch 1:  28%|██▊       | 139/493 [01:03<02:40,  2.21it/s, training_loss=0.167]
#
# Epoch 1:  28%|██▊       | 139/493 [01:03<02:40,  2.21it/s, training_loss=0.212]
#
# Epoch 1:  28%|██▊       | 140/493 [01:03<02:39,  2.21it/s, training_loss=0.212]
#
# Epoch 1:  28%|██▊       | 140/493 [01:04<02:39,  2.21it/s, training_loss=0.230]
#
# Epoch 1:  29%|██▊       | 141/493 [01:04<02:38,  2.22it/s, training_loss=0.230]
#
# Epoch 1:  29%|██▊       | 141/493 [01:04<02:38,  2.22it/s, training_loss=0.195]
#
# Epoch 1:  29%|██▉       | 142/493 [01:04<02:38,  2.22it/s, training_loss=0.195]
#
# Epoch 1:  29%|██▉       | 142/493 [01:05<02:38,  2.22it/s, training_loss=0.064]
#
# Epoch 1:  29%|██▉       | 143/493 [01:05<02:37,  2.22it/s, training_loss=0.064]
#
# Epoch 1:  29%|██▉       | 143/493 [01:05<02:37,  2.22it/s, training_loss=0.269]
#
# Epoch 1:  29%|██▉       | 144/493 [01:05<02:37,  2.22it/s, training_loss=0.269]
#
# Epoch 1:  29%|██▉       | 144/493 [01:06<02:37,  2.22it/s, training_loss=0.253]
#
# Epoch 1:  29%|██▉       | 145/493 [01:06<02:36,  2.22it/s, training_loss=0.253]
#
# Epoch 1:  29%|██▉       | 145/493 [01:06<02:36,  2.22it/s, training_loss=0.195]
#
# Epoch 1:  30%|██▉       | 146/493 [01:06<02:36,  2.21it/s, training_loss=0.195]
#
# Epoch 1:  30%|██▉       | 146/493 [01:06<02:36,  2.21it/s, training_loss=0.147]
#
# Epoch 1:  30%|██▉       | 147/493 [01:06<02:36,  2.22it/s, training_loss=0.147]
#
# Epoch 1:  30%|██▉       | 147/493 [01:07<02:36,  2.22it/s, training_loss=0.146]
#
# Epoch 1:  30%|███       | 148/493 [01:07<02:36,  2.20it/s, training_loss=0.146]
#
# Epoch 1:  30%|███       | 148/493 [01:07<02:36,  2.20it/s, training_loss=0.201]
#
# Epoch 1:  30%|███       | 149/493 [01:07<02:36,  2.20it/s, training_loss=0.201]
#
# Epoch 1:  30%|███       | 149/493 [01:08<02:36,  2.20it/s, training_loss=0.248]
#
# Epoch 1:  30%|███       | 150/493 [01:08<02:35,  2.20it/s, training_loss=0.248]
#
# Epoch 1:  30%|███       | 150/493 [01:08<02:35,  2.20it/s, training_loss=0.184]
#
# Epoch 1:  31%|███       | 151/493 [01:08<02:34,  2.21it/s, training_loss=0.184]
#
# Epoch 1:  31%|███       | 151/493 [01:09<02:34,  2.21it/s, training_loss=0.149]
#
# Epoch 1:  31%|███       | 152/493 [01:09<02:34,  2.21it/s, training_loss=0.149]
#
# Epoch 1:  31%|███       | 152/493 [01:09<02:34,  2.21it/s, training_loss=0.183]
#
# Epoch 1:  31%|███       | 153/493 [01:09<02:33,  2.21it/s, training_loss=0.183]
#
# Epoch 1:  31%|███       | 153/493 [01:10<02:33,  2.21it/s, training_loss=0.230]
#
# Epoch 1:  31%|███       | 154/493 [01:10<02:33,  2.21it/s, training_loss=0.230]
#
# Epoch 1:  31%|███       | 154/493 [01:10<02:33,  2.21it/s, training_loss=0.250]
#
# Epoch 1:  31%|███▏      | 155/493 [01:10<02:32,  2.21it/s, training_loss=0.250]
#
# Epoch 1:  31%|███▏      | 155/493 [01:11<02:32,  2.21it/s, training_loss=0.130]
#
# Epoch 1:  32%|███▏      | 156/493 [01:11<02:32,  2.21it/s, training_loss=0.130]
#
# Epoch 1:  32%|███▏      | 156/493 [01:11<02:32,  2.21it/s, training_loss=0.304]
#
# Epoch 1:  32%|███▏      | 157/493 [01:11<02:31,  2.22it/s, training_loss=0.304]
#
# Epoch 1:  32%|███▏      | 157/493 [01:11<02:31,  2.22it/s, training_loss=0.162]
#
# Epoch 1:  32%|███▏      | 158/493 [01:11<02:31,  2.21it/s, training_loss=0.162]
#
# Epoch 1:  32%|███▏      | 158/493 [01:12<02:31,  2.21it/s, training_loss=0.234]
#
# Epoch 1:  32%|███▏      | 159/493 [01:12<02:32,  2.19it/s, training_loss=0.234]
#
# Epoch 1:  32%|███▏      | 159/493 [01:12<02:32,  2.19it/s, training_loss=0.112]
#
# Epoch 1:  32%|███▏      | 160/493 [01:12<02:31,  2.20it/s, training_loss=0.112]
#
# Epoch 1:  32%|███▏      | 160/493 [01:13<02:31,  2.20it/s, training_loss=0.225]
#
# Epoch 1:  33%|███▎      | 161/493 [01:13<02:30,  2.21it/s, training_loss=0.225]
#
# Epoch 1:  33%|███▎      | 161/493 [01:13<02:30,  2.21it/s, training_loss=0.216]
#
# Epoch 1:  33%|███▎      | 162/493 [01:13<02:29,  2.21it/s, training_loss=0.216]
#
# Epoch 1:  33%|███▎      | 162/493 [01:14<02:29,  2.21it/s, training_loss=0.172]
#
# Epoch 1:  33%|███▎      | 163/493 [01:14<02:29,  2.21it/s, training_loss=0.172]
#
# Epoch 1:  33%|███▎      | 163/493 [01:14<02:29,  2.21it/s, training_loss=0.201]
#
# Epoch 1:  33%|███▎      | 164/493 [01:14<02:29,  2.20it/s, training_loss=0.201]
#
# Epoch 1:  33%|███▎      | 164/493 [01:15<02:29,  2.20it/s, training_loss=0.105]
#
# Epoch 1:  33%|███▎      | 165/493 [01:15<02:29,  2.20it/s, training_loss=0.105]
#
# Epoch 1:  33%|███▎      | 165/493 [01:15<02:29,  2.20it/s, training_loss=0.249]
#
# Epoch 1:  34%|███▎      | 166/493 [01:15<02:28,  2.20it/s, training_loss=0.249]
#
# Epoch 1:  34%|███▎      | 166/493 [01:16<02:28,  2.20it/s, training_loss=0.117]
#
# Epoch 1:  34%|███▍      | 167/493 [01:16<02:27,  2.21it/s, training_loss=0.117]
#
# Epoch 1:  34%|███▍      | 167/493 [01:16<02:27,  2.21it/s, training_loss=0.284]
#
# Epoch 1:  34%|███▍      | 168/493 [01:16<02:27,  2.21it/s, training_loss=0.284]
#
# Epoch 1:  34%|███▍      | 168/493 [01:16<02:27,  2.21it/s, training_loss=0.145]
#
# Epoch 1:  34%|███▍      | 169/493 [01:16<02:26,  2.20it/s, training_loss=0.145]
#
# Epoch 1:  34%|███▍      | 169/493 [01:17<02:26,  2.20it/s, training_loss=0.285]
#
# Epoch 1:  34%|███▍      | 170/493 [01:17<02:26,  2.21it/s, training_loss=0.285]
#
# Epoch 1:  34%|███▍      | 170/493 [01:17<02:26,  2.21it/s, training_loss=0.228]
#
# Epoch 1:  35%|███▍      | 171/493 [01:17<02:25,  2.21it/s, training_loss=0.228]
#
# Epoch 1:  35%|███▍      | 171/493 [01:18<02:25,  2.21it/s, training_loss=0.143]
#
# Epoch 1:  35%|███▍      | 172/493 [01:18<02:25,  2.21it/s, training_loss=0.143]
#
# Epoch 1:  35%|███▍      | 172/493 [01:18<02:25,  2.21it/s, training_loss=0.120]
#
# Epoch 1:  35%|███▌      | 173/493 [01:18<02:24,  2.21it/s, training_loss=0.120]
#
# Epoch 1:  35%|███▌      | 173/493 [01:19<02:24,  2.21it/s, training_loss=0.146]
#
# Epoch 1:  35%|███▌      | 174/493 [01:19<02:24,  2.21it/s, training_loss=0.146]
#
# Epoch 1:  35%|███▌      | 174/493 [01:19<02:24,  2.21it/s, training_loss=0.228]
#
# Epoch 1:  35%|███▌      | 175/493 [01:19<02:23,  2.21it/s, training_loss=0.228]
#
# Epoch 1:  35%|███▌      | 175/493 [01:20<02:23,  2.21it/s, training_loss=0.114]
#
# Epoch 1:  36%|███▌      | 176/493 [01:20<02:24,  2.19it/s, training_loss=0.114]
#
# Epoch 1:  36%|███▌      | 176/493 [01:20<02:24,  2.19it/s, training_loss=0.343]
#
# Epoch 1:  36%|███▌      | 177/493 [01:20<02:24,  2.18it/s, training_loss=0.343]
#
# Epoch 1:  36%|███▌      | 177/493 [01:21<02:24,  2.18it/s, training_loss=0.230]
#
# Epoch 1:  36%|███▌      | 178/493 [01:21<02:24,  2.19it/s, training_loss=0.230]
#
# Epoch 1:  36%|███▌      | 178/493 [01:21<02:24,  2.19it/s, training_loss=0.051]
#
# Epoch 1:  36%|███▋      | 179/493 [01:21<02:23,  2.19it/s, training_loss=0.051]
#
# Epoch 1:  36%|███▋      | 179/493 [01:21<02:23,  2.19it/s, training_loss=0.215]
#
# Epoch 1:  37%|███▋      | 180/493 [01:21<02:22,  2.20it/s, training_loss=0.215]
#
# Epoch 1:  37%|███▋      | 180/493 [01:22<02:22,  2.20it/s, training_loss=0.127]
#
# Epoch 1:  37%|███▋      | 181/493 [01:22<02:21,  2.20it/s, training_loss=0.127]
#
# Epoch 1:  37%|███▋      | 181/493 [01:22<02:21,  2.20it/s, training_loss=0.085]
#
# Epoch 1:  37%|███▋      | 182/493 [01:22<02:21,  2.20it/s, training_loss=0.085]
#
# Epoch 1:  37%|███▋      | 182/493 [01:23<02:21,  2.20it/s, training_loss=0.244]
#
# Epoch 1:  37%|███▋      | 183/493 [01:23<02:21,  2.19it/s, training_loss=0.244]
#
# Epoch 1:  37%|███▋      | 183/493 [01:23<02:21,  2.19it/s, training_loss=0.246]
#
# Epoch 1:  37%|███▋      | 184/493 [01:23<02:21,  2.19it/s, training_loss=0.246]
#
# Epoch 1:  37%|███▋      | 184/493 [01:24<02:21,  2.19it/s, training_loss=0.163]
#
# Epoch 1:  38%|███▊      | 185/493 [01:24<02:20,  2.20it/s, training_loss=0.163]
#
# Epoch 1:  38%|███▊      | 185/493 [01:24<02:20,  2.20it/s, training_loss=0.207]
#
# Epoch 1:  38%|███▊      | 186/493 [01:24<02:20,  2.19it/s, training_loss=0.207]
#
# Epoch 1:  38%|███▊      | 186/493 [01:25<02:20,  2.19it/s, training_loss=0.271]
#
# Epoch 1:  38%|███▊      | 187/493 [01:25<02:19,  2.19it/s, training_loss=0.271]
#
# Epoch 1:  38%|███▊      | 187/493 [01:25<02:19,  2.19it/s, training_loss=0.188]
#
# Epoch 1:  38%|███▊      | 188/493 [01:25<02:18,  2.20it/s, training_loss=0.188]
#
# Epoch 1:  38%|███▊      | 188/493 [01:26<02:18,  2.20it/s, training_loss=0.262]
#
# Epoch 1:  38%|███▊      | 189/493 [01:26<02:17,  2.20it/s, training_loss=0.262]
#
# Epoch 1:  38%|███▊      | 189/493 [01:26<02:17,  2.20it/s, training_loss=0.303]
#
# Epoch 1:  39%|███▊      | 190/493 [01:26<02:17,  2.20it/s, training_loss=0.303]
#
# Epoch 1:  39%|███▊      | 190/493 [01:26<02:17,  2.20it/s, training_loss=0.072]
#
# Epoch 1:  39%|███▊      | 191/493 [01:26<02:17,  2.20it/s, training_loss=0.072]
#
# Epoch 1:  39%|███▊      | 191/493 [01:27<02:17,  2.20it/s, training_loss=0.344]
#
# Epoch 1:  39%|███▉      | 192/493 [01:27<02:16,  2.21it/s, training_loss=0.344]
#
# Epoch 1:  39%|███▉      | 192/493 [01:27<02:16,  2.21it/s, training_loss=0.186]
#
# Epoch 1:  39%|███▉      | 193/493 [01:27<02:15,  2.21it/s, training_loss=0.186]
#
# Epoch 1:  39%|███▉      | 193/493 [01:28<02:15,  2.21it/s, training_loss=0.101]
#
# Epoch 1:  39%|███▉      | 194/493 [01:28<02:15,  2.21it/s, training_loss=0.101]
#
# Epoch 1:  39%|███▉      | 194/493 [01:28<02:15,  2.21it/s, training_loss=0.178]
#
# Epoch 1:  40%|███▉      | 195/493 [01:28<02:15,  2.19it/s, training_loss=0.178]
#
# Epoch 1:  40%|███▉      | 195/493 [01:29<02:15,  2.19it/s, training_loss=0.254]
#
# Epoch 1:  40%|███▉      | 196/493 [01:29<02:16,  2.17it/s, training_loss=0.254]
#
# Epoch 1:  40%|███▉      | 196/493 [01:29<02:16,  2.17it/s, training_loss=0.274]
#
# Epoch 1:  40%|███▉      | 197/493 [01:29<02:15,  2.18it/s, training_loss=0.274]
#
# Epoch 1:  40%|███▉      | 197/493 [01:30<02:15,  2.18it/s, training_loss=0.166]
#
# Epoch 1:  40%|████      | 198/493 [01:30<02:14,  2.19it/s, training_loss=0.166]
#
# Epoch 1:  40%|████      | 198/493 [01:30<02:14,  2.19it/s, training_loss=0.241]
#
# Epoch 1:  40%|████      | 199/493 [01:30<02:15,  2.17it/s, training_loss=0.241]
#
# Epoch 1:  40%|████      | 199/493 [01:31<02:15,  2.17it/s, training_loss=0.156]
#
# Epoch 1:  41%|████      | 200/493 [01:31<02:14,  2.17it/s, training_loss=0.156]
#
# Epoch 1:  41%|████      | 200/493 [01:31<02:14,  2.17it/s, training_loss=0.200]
#
# Epoch 1:  41%|████      | 201/493 [01:31<02:13,  2.19it/s, training_loss=0.200]
#
# Epoch 1:  41%|████      | 201/493 [01:32<02:13,  2.19it/s, training_loss=0.130]
#
# Epoch 1:  41%|████      | 202/493 [01:32<02:13,  2.18it/s, training_loss=0.130]
#
# Epoch 1:  41%|████      | 202/493 [01:32<02:13,  2.18it/s, training_loss=0.195]
#
# Epoch 1:  41%|████      | 203/493 [01:32<02:12,  2.19it/s, training_loss=0.195]
#
# Epoch 1:  41%|████      | 203/493 [01:32<02:12,  2.19it/s, training_loss=0.140]
#
# Epoch 1:  41%|████▏     | 204/493 [01:32<02:11,  2.20it/s, training_loss=0.140]
#
# Epoch 1:  41%|████▏     | 204/493 [01:33<02:11,  2.20it/s, training_loss=0.305]
#
# Epoch 1:  42%|████▏     | 205/493 [01:33<02:11,  2.20it/s, training_loss=0.305]
#
# Epoch 1:  42%|████▏     | 205/493 [01:33<02:11,  2.20it/s, training_loss=0.215]
#
# Epoch 1:  42%|████▏     | 206/493 [01:33<02:10,  2.21it/s, training_loss=0.215]
#
# Epoch 1:  42%|████▏     | 206/493 [01:34<02:10,  2.21it/s, training_loss=0.279]
#
# Epoch 1:  42%|████▏     | 207/493 [01:34<02:09,  2.20it/s, training_loss=0.279]
#
# Epoch 1:  42%|████▏     | 207/493 [01:34<02:09,  2.20it/s, training_loss=0.267]
#
# Epoch 1:  42%|████▏     | 208/493 [01:34<02:09,  2.21it/s, training_loss=0.267]
#
# Epoch 1:  42%|████▏     | 208/493 [01:35<02:09,  2.21it/s, training_loss=0.184]
#
# Epoch 1:  42%|████▏     | 209/493 [01:35<02:08,  2.21it/s, training_loss=0.184]
#
# Epoch 1:  42%|████▏     | 209/493 [01:35<02:08,  2.21it/s, training_loss=0.196]
#
# Epoch 1:  43%|████▎     | 210/493 [01:35<02:07,  2.21it/s, training_loss=0.196]
#
# Epoch 1:  43%|████▎     | 210/493 [01:36<02:07,  2.21it/s, training_loss=0.131]
#
# Epoch 1:  43%|████▎     | 211/493 [01:36<02:07,  2.21it/s, training_loss=0.131]
#
# Epoch 1:  43%|████▎     | 211/493 [01:36<02:07,  2.21it/s, training_loss=0.207]
#
# Epoch 1:  43%|████▎     | 212/493 [01:36<02:07,  2.21it/s, training_loss=0.207]
#
# Epoch 1:  43%|████▎     | 212/493 [01:36<02:07,  2.21it/s, training_loss=0.337]
#
# Epoch 1:  43%|████▎     | 213/493 [01:36<02:06,  2.21it/s, training_loss=0.337]
#
# Epoch 1:  43%|████▎     | 213/493 [01:37<02:06,  2.21it/s, training_loss=0.196]
#
# Epoch 1:  43%|████▎     | 214/493 [01:37<02:06,  2.21it/s, training_loss=0.196]
#
# Epoch 1:  43%|████▎     | 214/493 [01:37<02:06,  2.21it/s, training_loss=0.260]
#
# Epoch 1:  44%|████▎     | 215/493 [01:37<02:05,  2.21it/s, training_loss=0.260]
#
# Epoch 1:  44%|████▎     | 215/493 [01:38<02:05,  2.21it/s, training_loss=0.255]
#
# Epoch 1:  44%|████▍     | 216/493 [01:38<02:05,  2.21it/s, training_loss=0.255]
#
# Epoch 1:  44%|████▍     | 216/493 [01:38<02:05,  2.21it/s, training_loss=0.257]
#
# Epoch 1:  44%|████▍     | 217/493 [01:38<02:04,  2.21it/s, training_loss=0.257]
#
# Epoch 1:  44%|████▍     | 217/493 [01:39<02:04,  2.21it/s, training_loss=0.404]
#
# Epoch 1:  44%|████▍     | 218/493 [01:39<02:04,  2.21it/s, training_loss=0.404]
#
# Epoch 1:  44%|████▍     | 218/493 [01:39<02:04,  2.21it/s, training_loss=0.287]
#
# Epoch 1:  44%|████▍     | 219/493 [01:39<02:03,  2.21it/s, training_loss=0.287]
#
# Epoch 1:  44%|████▍     | 219/493 [01:40<02:03,  2.21it/s, training_loss=0.209]
#
# Epoch 1:  45%|████▍     | 220/493 [01:40<02:03,  2.21it/s, training_loss=0.209]
#
# Epoch 1:  45%|████▍     | 220/493 [01:40<02:03,  2.21it/s, training_loss=0.172]
#
# Epoch 1:  45%|████▍     | 221/493 [01:40<02:03,  2.21it/s, training_loss=0.172]
#
# Epoch 1:  45%|████▍     | 221/493 [01:41<02:03,  2.21it/s, training_loss=0.273]
#
# Epoch 1:  45%|████▌     | 222/493 [01:41<02:03,  2.20it/s, training_loss=0.273]
#
# Epoch 1:  45%|████▌     | 222/493 [01:41<02:03,  2.20it/s, training_loss=0.138]
#
# Epoch 1:  45%|████▌     | 223/493 [01:41<02:02,  2.21it/s, training_loss=0.138]
#
# Epoch 1:  45%|████▌     | 223/493 [01:41<02:02,  2.21it/s, training_loss=0.162]
#
# Epoch 1:  45%|████▌     | 224/493 [01:41<02:02,  2.19it/s, training_loss=0.162]
#
# Epoch 1:  45%|████▌     | 224/493 [01:42<02:02,  2.19it/s, training_loss=0.232]
#
# Epoch 1:  46%|████▌     | 225/493 [01:42<02:02,  2.19it/s, training_loss=0.232]
#
# Epoch 1:  46%|████▌     | 225/493 [01:42<02:02,  2.19it/s, training_loss=0.125]
#
# Epoch 1:  46%|████▌     | 226/493 [01:42<02:01,  2.20it/s, training_loss=0.125]
#
# Epoch 1:  46%|████▌     | 226/493 [01:43<02:01,  2.20it/s, training_loss=0.099]
#
# Epoch 1:  46%|████▌     | 227/493 [01:43<02:00,  2.20it/s, training_loss=0.099]
#
# Epoch 1:  46%|████▌     | 227/493 [01:43<02:00,  2.20it/s, training_loss=0.177]
#
# Epoch 1:  46%|████▌     | 228/493 [01:43<02:00,  2.20it/s, training_loss=0.177]
#
# Epoch 1:  46%|████▌     | 228/493 [01:44<02:00,  2.20it/s, training_loss=0.189]
#
# Epoch 1:  46%|████▋     | 229/493 [01:44<01:59,  2.20it/s, training_loss=0.189]
#
# Epoch 1:  46%|████▋     | 229/493 [01:44<01:59,  2.20it/s, training_loss=0.344]
#
# Epoch 1:  47%|████▋     | 230/493 [01:44<01:59,  2.20it/s, training_loss=0.344]
#
# Epoch 1:  47%|████▋     | 230/493 [01:45<01:59,  2.20it/s, training_loss=0.182]
#
# Epoch 1:  47%|████▋     | 231/493 [01:45<01:58,  2.20it/s, training_loss=0.182]
#
# Epoch 1:  47%|████▋     | 231/493 [01:45<01:58,  2.20it/s, training_loss=0.170]
#
# Epoch 1:  47%|████▋     | 232/493 [01:45<01:58,  2.20it/s, training_loss=0.170]
#
# Epoch 1:  47%|████▋     | 232/493 [01:46<01:58,  2.20it/s, training_loss=0.275]
#
# Epoch 1:  47%|████▋     | 233/493 [01:46<01:57,  2.20it/s, training_loss=0.275]
#
# Epoch 1:  47%|████▋     | 233/493 [01:46<01:57,  2.20it/s, training_loss=0.223]
#
# Epoch 1:  47%|████▋     | 234/493 [01:46<01:57,  2.21it/s, training_loss=0.223]
#
# Epoch 1:  47%|████▋     | 234/493 [01:46<01:57,  2.21it/s, training_loss=0.137]
#
# Epoch 1:  48%|████▊     | 235/493 [01:46<01:57,  2.20it/s, training_loss=0.137]
#
# Epoch 1:  48%|████▊     | 235/493 [01:47<01:57,  2.20it/s, training_loss=0.166]
#
# Epoch 1:  48%|████▊     | 236/493 [01:47<01:56,  2.20it/s, training_loss=0.166]
#
# Epoch 1:  48%|████▊     | 236/493 [01:47<01:56,  2.20it/s, training_loss=0.157]
#
# Epoch 1:  48%|████▊     | 237/493 [01:47<01:55,  2.21it/s, training_loss=0.157]
#
# Epoch 1:  48%|████▊     | 237/493 [01:48<01:55,  2.21it/s, training_loss=0.258]
#
# Epoch 1:  48%|████▊     | 238/493 [01:48<01:55,  2.21it/s, training_loss=0.258]
#
# Epoch 1:  48%|████▊     | 238/493 [01:48<01:55,  2.21it/s, training_loss=0.199]
#
# Epoch 1:  48%|████▊     | 239/493 [01:48<01:55,  2.21it/s, training_loss=0.199]
#
# Epoch 1:  48%|████▊     | 239/493 [01:49<01:55,  2.21it/s, training_loss=0.177]
#
# Epoch 1:  49%|████▊     | 240/493 [01:49<01:54,  2.21it/s, training_loss=0.177]
#
# Epoch 1:  49%|████▊     | 240/493 [01:49<01:54,  2.21it/s, training_loss=0.176]
#
# Epoch 1:  49%|████▉     | 241/493 [01:49<01:53,  2.21it/s, training_loss=0.176]
#
# Epoch 1:  49%|████▉     | 241/493 [01:50<01:53,  2.21it/s, training_loss=0.209]
#
# Epoch 1:  49%|████▉     | 242/493 [01:50<01:53,  2.22it/s, training_loss=0.209]
#
# Epoch 1:  49%|████▉     | 242/493 [01:50<01:53,  2.22it/s, training_loss=0.205]
#
# Epoch 1:  49%|████▉     | 243/493 [01:50<01:53,  2.20it/s, training_loss=0.205]
#
# Epoch 1:  49%|████▉     | 243/493 [01:51<01:53,  2.20it/s, training_loss=0.165]
#
# Epoch 1:  49%|████▉     | 244/493 [01:51<01:53,  2.20it/s, training_loss=0.165]
#
# Epoch 1:  49%|████▉     | 244/493 [01:51<01:53,  2.20it/s, training_loss=0.417]
#
# Epoch 1:  50%|████▉     | 245/493 [01:51<01:52,  2.20it/s, training_loss=0.417]
#
# Epoch 1:  50%|████▉     | 245/493 [01:51<01:52,  2.20it/s, training_loss=0.202]
#
# Epoch 1:  50%|████▉     | 246/493 [01:51<01:52,  2.20it/s, training_loss=0.202]
#
# Epoch 1:  50%|████▉     | 246/493 [01:52<01:52,  2.20it/s, training_loss=0.185]
#
# Epoch 1:  50%|█████     | 247/493 [01:52<01:51,  2.21it/s, training_loss=0.185]
#
# Epoch 1:  50%|█████     | 247/493 [01:52<01:51,  2.21it/s, training_loss=0.273]
#
# Epoch 1:  50%|█████     | 248/493 [01:52<01:50,  2.21it/s, training_loss=0.273]
#
# Epoch 1:  50%|█████     | 248/493 [01:53<01:50,  2.21it/s, training_loss=0.162]
#
# Epoch 1:  51%|█████     | 249/493 [01:53<01:50,  2.21it/s, training_loss=0.162]
#
# Epoch 1:  51%|█████     | 249/493 [01:53<01:50,  2.21it/s, training_loss=0.222]
#
# Epoch 1:  51%|█████     | 250/493 [01:53<01:50,  2.21it/s, training_loss=0.222]
#
# Epoch 1:  51%|█████     | 250/493 [01:54<01:50,  2.21it/s, training_loss=0.153]
#
# Epoch 1:  51%|█████     | 251/493 [01:54<01:49,  2.21it/s, training_loss=0.153]
#
# Epoch 1:  51%|█████     | 251/493 [01:54<01:49,  2.21it/s, training_loss=0.160]
#
# Epoch 1:  51%|█████     | 252/493 [01:54<01:49,  2.20it/s, training_loss=0.160]
#
# Epoch 1:  51%|█████     | 252/493 [01:55<01:49,  2.20it/s, training_loss=0.177]
#
# Epoch 1:  51%|█████▏    | 253/493 [01:55<01:49,  2.20it/s, training_loss=0.177]
#
# Epoch 1:  51%|█████▏    | 253/493 [01:55<01:49,  2.20it/s, training_loss=0.235]
#
# Epoch 1:  52%|█████▏    | 254/493 [01:55<01:48,  2.20it/s, training_loss=0.235]
#
# Epoch 1:  52%|█████▏    | 254/493 [01:56<01:48,  2.20it/s, training_loss=0.229]
#
# Epoch 1:  52%|█████▏    | 255/493 [01:56<01:48,  2.20it/s, training_loss=0.229]
#
# Epoch 1:  52%|█████▏    | 255/493 [01:56<01:48,  2.20it/s, training_loss=0.118]
#
# Epoch 1:  52%|█████▏    | 256/493 [01:56<01:47,  2.20it/s, training_loss=0.118]
#
# Epoch 1:  52%|█████▏    | 256/493 [01:56<01:47,  2.20it/s, training_loss=0.258]
#
# Epoch 1:  52%|█████▏    | 257/493 [01:56<01:47,  2.20it/s, training_loss=0.258]
#
# Epoch 1:  52%|█████▏    | 257/493 [01:57<01:47,  2.20it/s, training_loss=0.202]
#
# Epoch 1:  52%|█████▏    | 258/493 [01:57<01:46,  2.20it/s, training_loss=0.202]
#
# Epoch 1:  52%|█████▏    | 258/493 [01:57<01:46,  2.20it/s, training_loss=0.209]
#
# Epoch 1:  53%|█████▎    | 259/493 [01:57<01:46,  2.20it/s, training_loss=0.209]
#
# Epoch 1:  53%|█████▎    | 259/493 [01:58<01:46,  2.20it/s, training_loss=0.128]
#
# Epoch 1:  53%|█████▎    | 260/493 [01:58<01:46,  2.19it/s, training_loss=0.128]
#
# Epoch 1:  53%|█████▎    | 260/493 [01:58<01:46,  2.19it/s, training_loss=0.097]
#
# Epoch 1:  53%|█████▎    | 261/493 [01:58<01:46,  2.17it/s, training_loss=0.097]
#
# Epoch 1:  53%|█████▎    | 261/493 [01:59<01:46,  2.17it/s, training_loss=0.238]
#
# Epoch 1:  53%|█████▎    | 262/493 [01:59<01:45,  2.18it/s, training_loss=0.238]
#
# Epoch 1:  53%|█████▎    | 262/493 [01:59<01:45,  2.18it/s, training_loss=0.268]
#
# Epoch 1:  53%|█████▎    | 263/493 [01:59<01:45,  2.19it/s, training_loss=0.268]
#
# Epoch 1:  53%|█████▎    | 263/493 [02:00<01:45,  2.19it/s, training_loss=0.302]
#
# Epoch 1:  54%|█████▎    | 264/493 [02:00<01:44,  2.20it/s, training_loss=0.302]
#
# Epoch 1:  54%|█████▎    | 264/493 [02:00<01:44,  2.20it/s, training_loss=0.136]
#
# Epoch 1:  54%|█████▍    | 265/493 [02:00<01:43,  2.20it/s, training_loss=0.136]
#
# Epoch 1:  54%|█████▍    | 265/493 [02:01<01:43,  2.20it/s, training_loss=0.184]
#
# Epoch 1:  54%|█████▍    | 266/493 [02:01<01:43,  2.20it/s, training_loss=0.184]
#
# Epoch 1:  54%|█████▍    | 266/493 [02:01<01:43,  2.20it/s, training_loss=0.262]
#
# Epoch 1:  54%|█████▍    | 267/493 [02:01<01:42,  2.20it/s, training_loss=0.262]
#
# Epoch 1:  54%|█████▍    | 267/493 [02:01<01:42,  2.20it/s, training_loss=0.182]
#
# Epoch 1:  54%|█████▍    | 268/493 [02:01<01:42,  2.20it/s, training_loss=0.182]
#
# Epoch 1:  54%|█████▍    | 268/493 [02:02<01:42,  2.20it/s, training_loss=0.214]
#
# Epoch 1:  55%|█████▍    | 269/493 [02:02<01:41,  2.20it/s, training_loss=0.214]
#
# Epoch 1:  55%|█████▍    | 269/493 [02:02<01:41,  2.20it/s, training_loss=0.170]
#
# Epoch 1:  55%|█████▍    | 270/493 [02:02<01:42,  2.19it/s, training_loss=0.170]
#
# Epoch 1:  55%|█████▍    | 270/493 [02:03<01:42,  2.19it/s, training_loss=0.087]
#
# Epoch 1:  55%|█████▍    | 271/493 [02:03<01:41,  2.19it/s, training_loss=0.087]
#
# Epoch 1:  55%|█████▍    | 271/493 [02:03<01:41,  2.19it/s, training_loss=0.108]
#
# Epoch 1:  55%|█████▌    | 272/493 [02:03<01:40,  2.20it/s, training_loss=0.108]
#
# Epoch 1:  55%|█████▌    | 272/493 [02:04<01:40,  2.20it/s, training_loss=0.165]
#
# Epoch 1:  55%|█████▌    | 273/493 [02:04<01:40,  2.19it/s, training_loss=0.165]
#
# Epoch 1:  55%|█████▌    | 273/493 [02:04<01:40,  2.19it/s, training_loss=0.183]
#
# Epoch 1:  56%|█████▌    | 274/493 [02:04<01:39,  2.19it/s, training_loss=0.183]
#
# Epoch 1:  56%|█████▌    | 274/493 [02:05<01:39,  2.19it/s, training_loss=0.245]
#
# Epoch 1:  56%|█████▌    | 275/493 [02:05<01:38,  2.20it/s, training_loss=0.245]
#
# Epoch 1:  56%|█████▌    | 275/493 [02:05<01:38,  2.20it/s, training_loss=0.241]
#
# Epoch 1:  56%|█████▌    | 276/493 [02:05<01:38,  2.21it/s, training_loss=0.241]
#
# Epoch 1:  56%|█████▌    | 276/493 [02:06<01:38,  2.21it/s, training_loss=0.115]
#
# Epoch 1:  56%|█████▌    | 277/493 [02:06<01:38,  2.20it/s, training_loss=0.115]
#
# Epoch 1:  56%|█████▌    | 277/493 [02:06<01:38,  2.20it/s, training_loss=0.142]
#
# Epoch 1:  56%|█████▋    | 278/493 [02:06<01:37,  2.20it/s, training_loss=0.142]
#
# Epoch 1:  56%|█████▋    | 278/493 [02:06<01:37,  2.20it/s, training_loss=0.093]
#
# Epoch 1:  57%|█████▋    | 279/493 [02:06<01:37,  2.19it/s, training_loss=0.093]
#
# Epoch 1:  57%|█████▋    | 279/493 [02:07<01:37,  2.19it/s, training_loss=0.189]
#
# Epoch 1:  57%|█████▋    | 280/493 [02:07<01:37,  2.19it/s, training_loss=0.189]
#
# Epoch 1:  57%|█████▋    | 280/493 [02:07<01:37,  2.19it/s, training_loss=0.157]
#
# Epoch 1:  57%|█████▋    | 281/493 [02:07<01:36,  2.20it/s, training_loss=0.157]
#
# Epoch 1:  57%|█████▋    | 281/493 [02:08<01:36,  2.20it/s, training_loss=0.117]
#
# Epoch 1:  57%|█████▋    | 282/493 [02:08<01:35,  2.20it/s, training_loss=0.117]
#
# Epoch 1:  57%|█████▋    | 282/493 [02:08<01:35,  2.20it/s, training_loss=0.208]
#
# Epoch 1:  57%|█████▋    | 283/493 [02:08<01:35,  2.21it/s, training_loss=0.208]
#
# Epoch 1:  57%|█████▋    | 283/493 [02:09<01:35,  2.21it/s, training_loss=0.199]
#
# Epoch 1:  58%|█████▊    | 284/493 [02:09<01:34,  2.21it/s, training_loss=0.199]
#
# Epoch 1:  58%|█████▊    | 284/493 [02:09<01:34,  2.21it/s, training_loss=0.214]
#
# Epoch 1:  58%|█████▊    | 285/493 [02:09<01:34,  2.21it/s, training_loss=0.214]
#
# Epoch 1:  58%|█████▊    | 285/493 [02:10<01:34,  2.21it/s, training_loss=0.210]
#
# Epoch 1:  58%|█████▊    | 286/493 [02:10<01:33,  2.22it/s, training_loss=0.210]
#
# Epoch 1:  58%|█████▊    | 286/493 [02:10<01:33,  2.22it/s, training_loss=0.290]
#
# Epoch 1:  58%|█████▊    | 287/493 [02:10<01:33,  2.21it/s, training_loss=0.290]
#
# Epoch 1:  58%|█████▊    | 287/493 [02:11<01:33,  2.21it/s, training_loss=0.368]
#
# Epoch 1:  58%|█████▊    | 288/493 [02:11<01:32,  2.21it/s, training_loss=0.368]
#
# Epoch 1:  58%|█████▊    | 288/493 [02:11<01:32,  2.21it/s, training_loss=0.291]
#
# Epoch 1:  59%|█████▊    | 289/493 [02:11<01:32,  2.22it/s, training_loss=0.291]
#
# Epoch 1:  59%|█████▊    | 289/493 [02:11<01:32,  2.22it/s, training_loss=0.158]
#
# Epoch 1:  59%|█████▉    | 290/493 [02:11<01:31,  2.22it/s, training_loss=0.158]
#
# Epoch 1:  59%|█████▉    | 290/493 [02:12<01:31,  2.22it/s, training_loss=0.168]
#
# Epoch 1:  59%|█████▉    | 291/493 [02:12<01:31,  2.21it/s, training_loss=0.168]
#
# Epoch 1:  59%|█████▉    | 291/493 [02:12<01:31,  2.21it/s, training_loss=0.067]
#
# Epoch 1:  59%|█████▉    | 292/493 [02:12<01:30,  2.21it/s, training_loss=0.067]
#
# Epoch 1:  59%|█████▉    | 292/493 [02:13<01:30,  2.21it/s, training_loss=0.158]
#
# Epoch 1:  59%|█████▉    | 293/493 [02:13<01:30,  2.20it/s, training_loss=0.158]
#
# Epoch 1:  59%|█████▉    | 293/493 [02:13<01:30,  2.20it/s, training_loss=0.272]
#
# Epoch 1:  60%|█████▉    | 294/493 [02:13<01:30,  2.20it/s, training_loss=0.272]
#
# Epoch 1:  60%|█████▉    | 294/493 [02:14<01:30,  2.20it/s, training_loss=0.232]
#
# Epoch 1:  60%|█████▉    | 295/493 [02:14<01:30,  2.19it/s, training_loss=0.232]
#
# Epoch 1:  60%|█████▉    | 295/493 [02:14<01:30,  2.19it/s, training_loss=0.322]
#
# Epoch 1:  60%|██████    | 296/493 [02:14<01:29,  2.19it/s, training_loss=0.322]
#
# Epoch 1:  60%|██████    | 296/493 [02:15<01:29,  2.19it/s, training_loss=0.240]
#
# Epoch 1:  60%|██████    | 297/493 [02:15<01:29,  2.20it/s, training_loss=0.240]
#
# ...
#
# Epoch 10:  59%|█████▉    | 293/493 [02:12<01:30,  2.21it/s, training_loss=0.302]
#
# Epoch 10:  59%|█████▉    | 293/493 [02:13<01:30,  2.21it/s, training_loss=0.267]
#
# Epoch 10:  60%|█████▉    | 294/493 [02:13<01:30,  2.21it/s, training_loss=0.267]
#
# Epoch 10:  60%|█████▉    | 294/493 [02:13<01:30,  2.21it/s, training_loss=0.188]
#
# Epoch 10:  60%|█████▉    | 295/493 [02:13<01:29,  2.21it/s, training_loss=0.188]
#
# Epoch 10:  60%|█████▉    | 295/493 [02:14<01:29,  2.21it/s, training_loss=0.120]
#
# Epoch 10:  60%|██████    | 296/493 [02:14<01:28,  2.22it/s, training_loss=0.120]
#
# Epoch 10:  60%|██████    | 296/493 [02:14<01:28,  2.22it/s, training_loss=0.198]
#
# Epoch 10:  60%|██████    | 297/493 [02:14<01:28,  2.21it/s, training_loss=0.198]
#
# Epoch 10:  60%|██████    | 297/493 [02:15<01:28,  2.21it/s, training_loss=0.349]
#
# Epoch 10:  60%|██████    | 298/493 [02:15<01:27,  2.22it/s, training_loss=0.349]
#
# Epoch 10:  60%|██████    | 298/493 [02:15<01:27,  2.22it/s, training_loss=0.224]
#
# Epoch 10:  61%|██████    | 299/493 [02:15<01:27,  2.21it/s, training_loss=0.224]
#
# Epoch 10:  61%|██████    | 299/493 [02:16<01:27,  2.21it/s, training_loss=0.205]
#
# Epoch 10:  61%|██████    | 300/493 [02:16<01:27,  2.21it/s, training_loss=0.205]
#
# Epoch 10:  61%|██████    | 300/493 [02:16<01:27,  2.21it/s, training_loss=0.292]
#
# Epoch 10:  61%|██████    | 301/493 [02:16<01:26,  2.21it/s, training_loss=0.292]
#
# Epoch 10:  61%|██████    | 301/493 [02:16<01:26,  2.21it/s, training_loss=0.199]
#
# Epoch 10:  61%|██████▏   | 302/493 [02:16<01:26,  2.21it/s, training_loss=0.199]
#
# Epoch 10:  61%|██████▏   | 302/493 [02:17<01:26,  2.21it/s, training_loss=0.221]
#
# Epoch 10:  61%|██████▏   | 303/493 [02:17<01:25,  2.21it/s, training_loss=0.221]
#
# Epoch 10:  61%|██████▏   | 303/493 [02:17<01:25,  2.21it/s, training_loss=0.177]
#
# Epoch 10:  62%|██████▏   | 304/493 [02:17<01:25,  2.20it/s, training_loss=0.177]
#
# Epoch 10:  62%|██████▏   | 304/493 [02:18<01:25,  2.20it/s, training_loss=0.144]
#
# Epoch 10:  62%|██████▏   | 305/493 [02:18<01:25,  2.20it/s, training_loss=0.144]
#
# Epoch 10:  62%|██████▏   | 305/493 [02:18<01:25,  2.20it/s, training_loss=0.223]
#
# Epoch 10:  62%|██████▏   | 306/493 [02:18<01:25,  2.20it/s, training_loss=0.223]
#
# Epoch 10:  62%|██████▏   | 306/493 [02:19<01:25,  2.20it/s, training_loss=0.205]
#
# Epoch 10:  62%|██████▏   | 307/493 [02:19<01:24,  2.20it/s, training_loss=0.205]
#
# Epoch 10:  62%|██████▏   | 307/493 [02:19<01:24,  2.20it/s, training_loss=0.234]
#
# Epoch 10:  62%|██████▏   | 308/493 [02:19<01:24,  2.20it/s, training_loss=0.234]
#
# Epoch 10:  62%|██████▏   | 308/493 [02:20<01:24,  2.20it/s, training_loss=0.245]
#
# Epoch 10:  63%|██████▎   | 309/493 [02:20<01:23,  2.20it/s, training_loss=0.245]
#
# Epoch 10:  63%|██████▎   | 309/493 [02:20<01:23,  2.20it/s, training_loss=0.157]
#
# Epoch 10:  63%|██████▎   | 310/493 [02:20<01:22,  2.21it/s, training_loss=0.157]
#
# Epoch 10:  63%|██████▎   | 310/493 [02:21<01:22,  2.21it/s, training_loss=0.192]
#
# Epoch 10:  63%|██████▎   | 311/493 [02:21<01:22,  2.21it/s, training_loss=0.192]
#
# Epoch 10:  63%|██████▎   | 311/493 [02:21<01:22,  2.21it/s, training_loss=0.270]
#
# Epoch 10:  63%|██████▎   | 312/493 [02:21<01:21,  2.21it/s, training_loss=0.270]
#
# Epoch 10:  63%|██████▎   | 312/493 [02:21<01:21,  2.21it/s, training_loss=0.255]
#
# Epoch 10:  63%|██████▎   | 313/493 [02:21<01:21,  2.21it/s, training_loss=0.255]
#
# Epoch 10:  63%|██████▎   | 313/493 [02:22<01:21,  2.21it/s, training_loss=0.411]
#
# Epoch 10:  64%|██████▎   | 314/493 [02:22<01:21,  2.21it/s, training_loss=0.411]
#
# Epoch 10:  64%|██████▎   | 314/493 [02:22<01:21,  2.21it/s, training_loss=0.211]
#
# Epoch 10:  64%|██████▍   | 315/493 [02:22<01:20,  2.21it/s, training_loss=0.211]
#
# Epoch 10:  64%|██████▍   | 315/493 [02:23<01:20,  2.21it/s, training_loss=0.190]
#
# Epoch 10:  64%|██████▍   | 316/493 [02:23<01:20,  2.21it/s, training_loss=0.190]
#
# Epoch 10:  64%|██████▍   | 316/493 [02:23<01:20,  2.21it/s, training_loss=0.175]
#
# Epoch 10:  64%|██████▍   | 317/493 [02:23<01:19,  2.21it/s, training_loss=0.175]
#
# Epoch 10:  64%|██████▍   | 317/493 [02:24<01:19,  2.21it/s, training_loss=0.202]
#
# Epoch 10:  65%|██████▍   | 318/493 [02:24<01:19,  2.21it/s, training_loss=0.202]
#
# Epoch 10:  65%|██████▍   | 318/493 [02:24<01:19,  2.21it/s, training_loss=0.241]
#
# Epoch 10:  65%|██████▍   | 319/493 [02:24<01:18,  2.21it/s, training_loss=0.241]
#
# Epoch 10:  65%|██████▍   | 319/493 [02:25<01:18,  2.21it/s, training_loss=0.198]
#
# Epoch 10:  65%|██████▍   | 320/493 [02:25<01:18,  2.21it/s, training_loss=0.198]
#
# Epoch 10:  65%|██████▍   | 320/493 [02:25<01:18,  2.21it/s, training_loss=0.052]
#
# Epoch 10:  65%|██████▌   | 321/493 [02:25<01:17,  2.21it/s, training_loss=0.052]
#
# Epoch 10:  65%|██████▌   | 321/493 [02:25<01:17,  2.21it/s, training_loss=0.302]
#
# Epoch 10:  65%|██████▌   | 322/493 [02:25<01:17,  2.21it/s, training_loss=0.302]
#
# Epoch 10:  65%|██████▌   | 322/493 [02:26<01:17,  2.21it/s, training_loss=0.251]
#
# Epoch 10:  66%|██████▌   | 323/493 [02:26<01:16,  2.22it/s, training_loss=0.251]
#
# Epoch 10:  66%|██████▌   | 323/493 [02:26<01:16,  2.22it/s, training_loss=0.273]
#
# Epoch 10:  66%|██████▌   | 324/493 [02:26<01:16,  2.22it/s, training_loss=0.273]
#
# Epoch 10:  66%|██████▌   | 324/493 [02:27<01:16,  2.22it/s, training_loss=0.348]
#
# Epoch 10:  66%|██████▌   | 325/493 [02:27<01:15,  2.22it/s, training_loss=0.348]
#
# Epoch 10:  66%|██████▌   | 325/493 [02:27<01:15,  2.22it/s, training_loss=0.192]
#
# Epoch 10:  66%|██████▌   | 326/493 [02:27<01:15,  2.22it/s, training_loss=0.192]
#
# Epoch 10:  66%|██████▌   | 326/493 [02:28<01:15,  2.22it/s, training_loss=0.328]
#
# Epoch 10:  66%|██████▋   | 327/493 [02:28<01:14,  2.22it/s, training_loss=0.328]
#
# Epoch 10:  66%|██████▋   | 327/493 [02:28<01:14,  2.22it/s, training_loss=0.173]
#
# Epoch 10:  67%|██████▋   | 328/493 [02:28<01:14,  2.22it/s, training_loss=0.173]
#
# Epoch 10:  67%|██████▋   | 328/493 [02:29<01:14,  2.22it/s, training_loss=0.141]
#
# Epoch 10:  67%|██████▋   | 329/493 [02:29<01:13,  2.22it/s, training_loss=0.141]
#
# Epoch 10:  67%|██████▋   | 329/493 [02:29<01:13,  2.22it/s, training_loss=0.281]
#
# Epoch 10:  67%|██████▋   | 330/493 [02:29<01:14,  2.20it/s, training_loss=0.281]
#
# Epoch 10:  67%|██████▋   | 330/493 [02:30<01:14,  2.20it/s, training_loss=0.076]
#
# Epoch 10:  67%|██████▋   | 331/493 [02:30<01:13,  2.21it/s, training_loss=0.076]
#
# Epoch 10:  67%|██████▋   | 331/493 [02:30<01:13,  2.21it/s, training_loss=0.176]
#
# Epoch 10:  67%|██████▋   | 332/493 [02:30<01:12,  2.21it/s, training_loss=0.176]
#
# Epoch 10:  67%|██████▋   | 332/493 [02:30<01:12,  2.21it/s, training_loss=0.154]
#
# Epoch 10:  68%|██████▊   | 333/493 [02:30<01:12,  2.20it/s, training_loss=0.154]
#
# Epoch 10:  68%|██████▊   | 333/493 [02:31<01:12,  2.20it/s, training_loss=0.193]
#
# Epoch 10:  68%|██████▊   | 334/493 [02:31<01:12,  2.20it/s, training_loss=0.193]
#
# Epoch 10:  68%|██████▊   | 334/493 [02:31<01:12,  2.20it/s, training_loss=0.240]
#
# Epoch 10:  68%|██████▊   | 335/493 [02:31<01:11,  2.21it/s, training_loss=0.240]
#
# Epoch 10:  68%|██████▊   | 335/493 [02:32<01:11,  2.21it/s, training_loss=0.227]
#
# Epoch 10:  68%|██████▊   | 336/493 [02:32<01:10,  2.21it/s, training_loss=0.227]
#
# Epoch 10:  68%|██████▊   | 336/493 [02:32<01:10,  2.21it/s, training_loss=0.299]
#
# Epoch 10:  68%|██████▊   | 337/493 [02:32<01:10,  2.21it/s, training_loss=0.299]
#
# Epoch 10:  68%|██████▊   | 337/493 [02:33<01:10,  2.21it/s, training_loss=0.188]
#
# Epoch 10:  69%|██████▊   | 338/493 [02:33<01:09,  2.22it/s, training_loss=0.188]
#
# Epoch 10:  69%|██████▊   | 338/493 [02:33<01:09,  2.22it/s, training_loss=0.211]
#
# Epoch 10:  69%|██████▉   | 339/493 [02:33<01:09,  2.20it/s, training_loss=0.211]
#
# Epoch 10:  69%|██████▉   | 339/493 [02:34<01:09,  2.20it/s, training_loss=0.221]
#
# Epoch 10:  69%|██████▉   | 340/493 [02:34<01:09,  2.20it/s, training_loss=0.221]
#
# Epoch 10:  69%|██████▉   | 340/493 [02:34<01:09,  2.20it/s, training_loss=0.166]
#
# Epoch 10:  69%|██████▉   | 341/493 [02:34<01:08,  2.21it/s, training_loss=0.166]
#
# Epoch 10:  69%|██████▉   | 341/493 [02:35<01:08,  2.21it/s, training_loss=0.189]
#
# Epoch 10:  69%|██████▉   | 342/493 [02:35<01:08,  2.21it/s, training_loss=0.189]
#
# Epoch 10:  69%|██████▉   | 342/493 [02:35<01:08,  2.21it/s, training_loss=0.212]
#
# Epoch 10:  70%|██████▉   | 343/493 [02:35<01:07,  2.22it/s, training_loss=0.212]
#
# Epoch 10:  70%|██████▉   | 343/493 [02:35<01:07,  2.22it/s, training_loss=0.258]
#
# Epoch 10:  70%|██████▉   | 344/493 [02:35<01:07,  2.20it/s, training_loss=0.258]
#
# Epoch 10:  70%|██████▉   | 344/493 [02:36<01:07,  2.20it/s, training_loss=0.264]
#
# Epoch 10:  70%|██████▉   | 345/493 [02:36<01:07,  2.20it/s, training_loss=0.264]
#
# Epoch 10:  70%|██████▉   | 345/493 [02:36<01:07,  2.20it/s, training_loss=0.086]
#
# Epoch 10:  70%|███████   | 346/493 [02:36<01:06,  2.20it/s, training_loss=0.086]
#
# Epoch 10:  70%|███████   | 346/493 [02:37<01:06,  2.20it/s, training_loss=0.215]
#
# Epoch 10:  70%|███████   | 347/493 [02:37<01:06,  2.21it/s, training_loss=0.215]
#
# Epoch 10:  70%|███████   | 347/493 [02:37<01:06,  2.21it/s, training_loss=0.210]
#
# Epoch 10:  71%|███████   | 348/493 [02:37<01:05,  2.21it/s, training_loss=0.210]
#
# Epoch 10:  71%|███████   | 348/493 [02:38<01:05,  2.21it/s, training_loss=0.157]
#
# Epoch 10:  71%|███████   | 349/493 [02:38<01:05,  2.21it/s, training_loss=0.157]
#
# Epoch 10:  71%|███████   | 349/493 [02:38<01:05,  2.21it/s, training_loss=0.214]
#
# Epoch 10:  71%|███████   | 350/493 [02:38<01:04,  2.21it/s, training_loss=0.214]
#
# Epoch 10:  71%|███████   | 350/493 [02:39<01:04,  2.21it/s, training_loss=0.213]
#
# Epoch 10:  71%|███████   | 351/493 [02:39<01:04,  2.22it/s, training_loss=0.213]
#
# Epoch 10:  71%|███████   | 351/493 [02:39<01:04,  2.22it/s, training_loss=0.258]
#
# Epoch 10:  71%|███████▏  | 352/493 [02:39<01:03,  2.22it/s, training_loss=0.258]
#
# Epoch 10:  71%|███████▏  | 352/493 [02:40<01:03,  2.22it/s, training_loss=0.188]
#
# Epoch 10:  72%|███████▏  | 353/493 [02:40<01:03,  2.20it/s, training_loss=0.188]
#
# Epoch 10:  72%|███████▏  | 353/493 [02:40<01:03,  2.20it/s, training_loss=0.176]
#
# Epoch 10:  72%|███████▏  | 354/493 [02:40<01:03,  2.20it/s, training_loss=0.176]
#
# Epoch 10:  72%|███████▏  | 354/493 [02:40<01:03,  2.20it/s, training_loss=0.226]
#
# Epoch 10:  72%|███████▏  | 355/493 [02:40<01:02,  2.21it/s, training_loss=0.226]
#
# Epoch 10:  72%|███████▏  | 355/493 [02:41<01:02,  2.21it/s, training_loss=0.218]
#
# Epoch 10:  72%|███████▏  | 356/493 [02:41<01:02,  2.20it/s, training_loss=0.218]
#
# Epoch 10:  72%|███████▏  | 356/493 [02:41<01:02,  2.20it/s, training_loss=0.184]
#
# Epoch 10:  72%|███████▏  | 357/493 [02:41<01:01,  2.21it/s, training_loss=0.184]
#
# Epoch 10:  72%|███████▏  | 357/493 [02:42<01:01,  2.21it/s, training_loss=0.156]
#
# Epoch 10:  73%|███████▎  | 358/493 [02:42<01:01,  2.20it/s, training_loss=0.156]
#
# Epoch 10:  73%|███████▎  | 358/493 [02:42<01:01,  2.20it/s, training_loss=0.218]
#
# Epoch 10:  73%|███████▎  | 359/493 [02:42<01:00,  2.20it/s, training_loss=0.218]
#
# Epoch 10:  73%|███████▎  | 359/493 [02:43<01:00,  2.20it/s, training_loss=0.197]
#
# Epoch 10:  73%|███████▎  | 360/493 [02:43<01:00,  2.20it/s, training_loss=0.197]
#
# Epoch 10:  73%|███████▎  | 360/493 [02:43<01:00,  2.20it/s, training_loss=0.184]
#
# Epoch 10:  73%|███████▎  | 361/493 [02:43<00:59,  2.21it/s, training_loss=0.184]
#
# Epoch 10:  73%|███████▎  | 361/493 [02:44<00:59,  2.21it/s, training_loss=0.168]
#
# Epoch 10:  73%|███████▎  | 362/493 [02:44<00:59,  2.21it/s, training_loss=0.168]
#
# Epoch 10:  73%|███████▎  | 362/493 [02:44<00:59,  2.21it/s, training_loss=0.204]
#
# Epoch 10:  74%|███████▎  | 363/493 [02:44<00:58,  2.21it/s, training_loss=0.204]
#
# Epoch 10:  74%|███████▎  | 363/493 [02:45<00:58,  2.21it/s, training_loss=0.221]
#
# Epoch 10:  74%|███████▍  | 364/493 [02:45<00:58,  2.21it/s, training_loss=0.221]
#
# Epoch 10:  74%|███████▍  | 364/493 [02:45<00:58,  2.21it/s, training_loss=0.289]
#
# Epoch 10:  74%|███████▍  | 365/493 [02:45<00:58,  2.20it/s, training_loss=0.289]
#
# Epoch 10:  74%|███████▍  | 365/493 [02:45<00:58,  2.20it/s, training_loss=0.323]
#
# Epoch 10:  74%|███████▍  | 366/493 [02:45<00:57,  2.20it/s, training_loss=0.323]
#
# Epoch 10:  74%|███████▍  | 366/493 [02:46<00:57,  2.20it/s, training_loss=0.111]
#
# Epoch 10:  74%|███████▍  | 367/493 [02:46<00:57,  2.20it/s, training_loss=0.111]
#
# Epoch 10:  74%|███████▍  | 367/493 [02:46<00:57,  2.20it/s, training_loss=0.302]
#
# Epoch 10:  75%|███████▍  | 368/493 [02:46<00:57,  2.19it/s, training_loss=0.302]
#
# Epoch 10:  75%|███████▍  | 368/493 [02:47<00:57,  2.19it/s, training_loss=0.291]
#
# Epoch 10:  75%|███████▍  | 369/493 [02:47<00:56,  2.19it/s, training_loss=0.291]
#
# Epoch 10:  75%|███████▍  | 369/493 [02:47<00:56,  2.19it/s, training_loss=0.167]
#
# Epoch 10:  75%|███████▌  | 370/493 [02:47<00:55,  2.20it/s, training_loss=0.167]
#
# Epoch 10:  75%|███████▌  | 370/493 [02:48<00:55,  2.20it/s, training_loss=0.161]
#
# Epoch 10:  75%|███████▌  | 371/493 [02:48<00:55,  2.19it/s, training_loss=0.161]
#
# Epoch 10:  75%|███████▌  | 371/493 [02:48<00:55,  2.19it/s, training_loss=0.190]
#
# Epoch 10:  75%|███████▌  | 372/493 [02:48<00:55,  2.20it/s, training_loss=0.190]
#
# Epoch 10:  75%|███████▌  | 372/493 [02:49<00:55,  2.20it/s, training_loss=0.087]
#
# Epoch 10:  76%|███████▌  | 373/493 [02:49<00:54,  2.20it/s, training_loss=0.087]
#
# Epoch 10:  76%|███████▌  | 373/493 [02:49<00:54,  2.20it/s, training_loss=0.238]
#
# Epoch 10:  76%|███████▌  | 374/493 [02:49<00:53,  2.21it/s, training_loss=0.238]
#
# Epoch 10:  76%|███████▌  | 374/493 [02:50<00:53,  2.21it/s, training_loss=0.257]
#
# Epoch 10:  76%|███████▌  | 375/493 [02:50<00:53,  2.21it/s, training_loss=0.257]
#
# Epoch 10:  76%|███████▌  | 375/493 [02:50<00:53,  2.21it/s, training_loss=0.135]
#
# Epoch 10:  76%|███████▋  | 376/493 [02:50<00:52,  2.21it/s, training_loss=0.135]
#
# Epoch 10:  76%|███████▋  | 376/493 [02:50<00:52,  2.21it/s, training_loss=0.188]
#
# Epoch 10:  76%|███████▋  | 377/493 [02:50<00:52,  2.21it/s, training_loss=0.188]
#
# Epoch 10:  76%|███████▋  | 377/493 [02:51<00:52,  2.21it/s, training_loss=0.131]
#
# Epoch 10:  77%|███████▋  | 378/493 [02:51<00:52,  2.21it/s, training_loss=0.131]
#
# Epoch 10:  77%|███████▋  | 378/493 [02:51<00:52,  2.21it/s, training_loss=0.262]
#
# Epoch 10:  77%|███████▋  | 379/493 [02:51<00:51,  2.21it/s, training_loss=0.262]
#
# Epoch 10:  77%|███████▋  | 379/493 [02:52<00:51,  2.21it/s, training_loss=0.344]
#
# Epoch 10:  77%|███████▋  | 380/493 [02:52<00:51,  2.19it/s, training_loss=0.344]
#
# Epoch 10:  77%|███████▋  | 380/493 [02:52<00:51,  2.19it/s, training_loss=0.104]
#
# Epoch 10:  77%|███████▋  | 381/493 [02:52<00:51,  2.19it/s, training_loss=0.104]
#
# Epoch 10:  77%|███████▋  | 381/493 [02:53<00:51,  2.19it/s, training_loss=0.191]
#
# Epoch 10:  77%|███████▋  | 382/493 [02:53<00:50,  2.20it/s, training_loss=0.191]
#
# Epoch 10:  77%|███████▋  | 382/493 [02:53<00:50,  2.20it/s, training_loss=0.218]
#
# Epoch 10:  78%|███████▊  | 383/493 [02:53<00:49,  2.20it/s, training_loss=0.218]
#
# Epoch 10:  78%|███████▊  | 383/493 [02:54<00:49,  2.20it/s, training_loss=0.222]
#
# Epoch 10:  78%|███████▊  | 384/493 [02:54<00:49,  2.21it/s, training_loss=0.222]
#
# Epoch 10:  78%|███████▊  | 384/493 [02:54<00:49,  2.21it/s, training_loss=0.156]
#
# Epoch 10:  78%|███████▊  | 385/493 [02:54<00:49,  2.20it/s, training_loss=0.156]
#
# Epoch 10:  78%|███████▊  | 385/493 [02:55<00:49,  2.20it/s, training_loss=0.172]
#
# Epoch 10:  78%|███████▊  | 386/493 [02:55<00:49,  2.18it/s, training_loss=0.172]
#
# Epoch 10:  78%|███████▊  | 386/493 [02:55<00:49,  2.18it/s, training_loss=0.231]
#
# Epoch 10:  78%|███████▊  | 387/493 [02:55<00:49,  2.14it/s, training_loss=0.231]
#
# Epoch 10:  78%|███████▊  | 387/493 [02:55<00:49,  2.14it/s, training_loss=0.167]
#
# Epoch 10:  79%|███████▊  | 388/493 [02:55<00:49,  2.12it/s, training_loss=0.167]
#
# Epoch 10:  79%|███████▊  | 388/493 [02:56<00:49,  2.12it/s, training_loss=0.236]
#
# Epoch 10:  79%|███████▉  | 389/493 [02:56<00:48,  2.14it/s, training_loss=0.236]
#
# Epoch 10:  79%|███████▉  | 389/493 [02:56<00:48,  2.14it/s, training_loss=0.227]
#
# Epoch 10:  79%|███████▉  | 390/493 [02:56<00:47,  2.16it/s, training_loss=0.227]

# %%
model=BertForSequenceClassification.from_pretrained(
                'bert-base-uncased',
                 num_labels=19, 
                  output_attentions=False, 
                 output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ####We choose the model from the last epoch, here the 8th epoch.

# %%
model.load_state_dict(torch.load('/content/BERT_ft_epoch10.model', map_location=torch.device('cuda')))
# Out:
# <All keys matched successfully>

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model.to(device)
print(device)
# Out:
# cuda

# %%
_, prediction, true_vals= evaluate(dataloader_test)

# %% [markdown]
# ####F1 score

# %%
f1_score_func(prediction, true_vals)
# Out:
# 0.6412352268761154

# %%
accuracy_per_class(prediction, true_vals)
# Out:
# Class:O
# Accuracy:2746/3000
#
# Class:Black-and-White_Fallacy
# Accuracy:0/26
#
# Class:Loaded_Language
# Accuracy:247/436
#
# Class:Flag-Waving
# Accuracy:25/96
#
# Class:Name_Calling,Labeling
# Accuracy:50/209
#
# Class:Slogans
# Accuracy:0/36
#
# Class:Causal_Oversimplification
# Accuracy:0/33
#
# Class:Whataboutism
# Accuracy:0/25
#
# Class:Exaggeration,Minimisation
# Accuracy:4/99
#
# Class:Doubt
# Accuracy:7/89
#
# Class:Appeal_to_Authority
# Accuracy:0/56
#
# Class:Repetition
# Accuracy:6/195
#
# Class:Appeal_to_fear-prejudice
# Accuracy:1/130
#
# Class:Thought-terminating_Cliches
# Accuracy:0/22
#
# Class:Bandwagon
# Accuracy:0/4
#
# Class:Red_Herring
# Accuracy:0/15
#
# Class:Reductio_ad_hitlerum
# Accuracy:0/11
#
# Class:Obfuscation,Intentional_Vagueness,Confusion
# Accuracy:0/6
#
# Class:Straw_Men
# Accuracy:0/2

# %%
print(len(prediction))
assert(len(predictions)==len(df_test))
# Out:
# 4490

# %%
a=prediction[4000]
print("an example of the predicted vectors is: ", a)
# Out:
# an example of the predicted vectors is:  [ 7.7178917  -1.1620193   0.5262173  -1.5242306  -0.3068546  -1.0497875
#  -0.7470739  -1.6815195  -0.6961153   0.5543403   0.302957    0.562094
#  -0.5063292  -0.36377698 -1.7534236  -1.2366631  -1.8603466  -1.4071819
#  -1.6673759 ]

# %%
pred=[]
for i in range (len(prediction)):
  pred.append(np.argmax(prediction[i]).flatten())

# %%
print(pred[9])
# Out:
# [0]

# %%
print(len(true_vals))
# Out:
# 4490

# %%
print(true_vals[1000])
# Out:
# 1

# %%
from sklearn.metrics import precision_recall_fscore_support as score

#predicted = [1,2,3,4,5,1,2,1,1,4,5] 
#y_test = [1,2,3,4,5,1,2,1,1,4,1]

precision, recall, fscore, support = score(true_vals, pred)

#print('precision: {}'.format(precision))
#print('recall: {}'.format(recall))
#print('fscore: {}'.format(fscore))
#print('support: {}'.format(support))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df1 = pd.DataFrame({ 'precision': precision, 'recall':recall, 'Fscore':fscore, 'support':support })

# %%
df1.head
# Out:
# <bound method NDFrame.head of     precision    recall    Fscore  support
# 0    0.810269  0.915333  0.859602     3000
# 1    0.000000  0.000000  0.000000       26
# 2    0.352354  0.566514  0.434477      436
# 3    0.301205  0.260417  0.279330       96
# 4    0.340136  0.239234  0.280899      209
# 5    0.000000  0.000000  0.000000       36
# 6    0.000000  0.000000  0.000000       33
# 7    0.000000  0.000000  0.000000       25
# 8    0.235294  0.040404  0.068966       99
# 9    0.082353  0.078652  0.080460       89
# 10   0.000000  0.000000  0.000000       56
# 11   0.120000  0.030769  0.048980      195
# 12   0.090909  0.007692  0.014184      130
# 13   0.000000  0.000000  0.000000       22
# 14   0.000000  0.000000  0.000000        4
# 15   0.000000  0.000000  0.000000       15
# 16   0.000000  0.000000  0.000000       11
# 17   0.000000  0.000000  0.000000        6
# 18   0.000000  0.000000  0.000000        2>

# %%
from tabulate import tabulate

print(tabulate(df1, headers='keys', tablefmt='psql'))
# Out:
# +----+-------------+------------+-----------+-----------+
# |    |   precision |     recall |    Fscore |   support |
# |----+-------------+------------+-----------+-----------|
# |  0 |   0.810269  | 0.915333   | 0.859602  |      3000 |
# |  1 |   0         | 0          | 0         |        26 |
# |  2 |   0.352354  | 0.566514   | 0.434477  |       436 |
# |  3 |   0.301205  | 0.260417   | 0.27933   |        96 |
# |  4 |   0.340136  | 0.239234   | 0.280899  |       209 |
# |  5 |   0         | 0          | 0         |        36 |
# |  6 |   0         | 0          | 0         |        33 |
# |  7 |   0         | 0          | 0         |        25 |
# |  8 |   0.235294  | 0.040404   | 0.0689655 |        99 |
# |  9 |   0.0823529 | 0.0786517  | 0.0804598 |        89 |
# | 10 |   0         | 0          | 0         |        56 |
# | 11 |   0.12      | 0.0307692  | 0.0489796 |       195 |
# | 12 |   0.0909091 | 0.00769231 | 0.0141844 |       130 |
# | 13 |   0         | 0          | 0         |        22 |
# | 14 |   0         | 0          | 0         |         4 |
# | 15 |   0         | 0          | 0         |        15 |
# | 16 |   0         | 0          | 0         |        11 |
# | 17 |   0         | 0          | 0         |         6 |
# | 18 |   0         | 0          | 0         |         2 |
# +----+-------------+------------+-----------+-----------+
